# %%
import requests
import json

# %%
overpass_url = "http://overpass-api.de/api/interpreter"
overpass_query = """
[out:json];
area[name="Greater London"];
(node[~"."~"."](area);
);
out meta;
out center;
"""
response = requests.get(overpass_url,
                       params={'data': overpass_query})
data = response.json()

data

#element['tags']
# Out:
# {u'elements': [{u'changeset': 58796803,
#    u'id': 99939,
#    u'lat': 51.5224429,
#    u'lon': -0.1554618,
#    u'tags': {u'highway': u'traffic_signals',
#     u'traffic_signals:direction': u'forward'},
#    u'timestamp': u'2018-05-08T19:12:46Z',
#    u'type': u'node',
#    u'uid': 17292,
#    u'user': u'jpennycook',
#    u'version': 5},
#   {u'changeset': 14954844,
#    u'id': 99941,
#    u'lat': 51.5231639,
#    u'lon': -0.1553793,
#    u'tags': {u'barrier': u'lift_gate'},
#    u'timestamp': u'2013-02-08T11:25:11Z',
#    u'type': u'node',
#    u'uid': 24119,
#    u'user': u'Mauls',
#    u'version': 2},
#   {u'changeset': 37864587,
#    u'id': 101831,
#    u'lat': 51.5356116,
#    u'lon': -0.1470438,
#    u'tags': {u'crossing': u'traffic_signals',
#     u'crossing_ref': u'pelican',
#     u'highway': u'crossing'},
#    u'timestamp': u'2016-03-16T08:11:39Z',
#    u'type': u'node',
#    u'uid': 1016290,
#    u'user': u'ika-chan! UK',
#    u'version': 9},
#   {u'changeset': 60451542,
#    u'id': 101833,
#    u'lat': 51.5350997,
#    u'lon': -0.1588547,
#    u'tags': {u'crossing': u'unmarked',
#     u'crossing:island': u'yes',
#     u'highway': u'crossing'},
#    u'timestamp': u'2018-07-06T02:24:07Z',
#    u'type': u'node',
#    u'uid': 322039,
#    u'user': u'MacLondon',
#    u'version': 3},
#   {u'changeset': 51518423,
#    u'id': 101839,
#    u'lat': 51.5375104,
#    u'lon': -0.1526868,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2017-08-28T18:27:25Z',
#    u'type': u'node',
#    u'uid': 2961845,
#    u'user': u'Nikolay M',
#    u'version': 5},
#   {u'changeset': 37864587,
#    u'id': 101843,
#    u'lat': 51.534922,
#    u'lon': -0.163653,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2016-03-16T08:11:39Z',
#    u'type': u'node',
#    u'uid': 1016290,
#    u'user': u'ika-chan! UK',
#    u'version': 3},
#   {u'changeset': 60450987,
#    u'id': 101849,
#    u'lat': 51.5324547,
#    u'lon': -0.1642465,
#    u'tags': {u'crossing': u'unmarked',
#     u'crossing:island': u'yes',
#     u'highway': u'crossing'},
#    u'timestamp': u'2018-07-06T01:24:59Z',
#    u'type': u'node',
#    u'uid': 322039,
#    u'user': u'MacLondon',
#    u'version': 5},
#   {u'changeset': 55385862,
#    u'id': 101877,
#    u'lat': 51.5287068,
#    u'lon': -0.1635849,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2018-01-12T17:05:00Z',
#    u'type': u'node',
#    u'uid': 486343,
#    u'user': u'peregrination',
#    u'version': 4},
#   {u'changeset': 55385862,
#    u'id': 101888,
#    u'lat': 51.5359175,
#    u'lon': -0.1760666,
#    u'tags': {u'highway': u'crossing'},
#    u'timestamp': u'2018-01-12T17:05:02Z',
#    u'type': u'node',
#    u'uid': 486343,
#    u'user': u'peregrination',
#    u'version': 5},
#   {u'changeset': 55385862,
#    u'id': 101889,
#    u'lat': 51.5363944,
#    u'lon': -0.1763089,
#    u'tags': {u'crossing': u'traffic_signals', u'highway': u'crossing'},
#    u'timestamp': u'2018-01-12T17:05:02Z',
#    u'type': u'node',
#    u'uid': 486343,
#    u'user': u'peregrination',
#    u'version': 7},
#   {u'changeset': 24636071,
#    u'id': 101894,
#    u'lat': 51.5434816,
#    u'lon': -0.1751371,
#    u'tags': {u'bicycle': u'yes',
#     u'crossing': u'traffic_signals',
#     u'crossing_ref': u'toucan',
#     u'highway': u'crossing',
#     u'segregated': u'no'},
#    u'timestamp': u'2014-08-09T15:22:16Z',
#    u'type': u'node',
#    u'uid': 1016290,
#    u'user': u'ika-chan! UK',
#    u'version': 6},
#   {u'changeset': 24636071,
#    u'id': 101898,
#    u'lat': 51.5454071,
#    u'lon': -0.1774342,
#    u'tags': {u'crossing': u'traffic_signals',
#     u'crossing_ref': u'pelican',
#     u'highway': u'traffic_signals'},
#    u'timestamp': u'2014-08-09T15:22:16Z',
#    u'type': u'node',
#    u'uid': 1016290,
#    u'user': u'ika-chan! UK',
#    u'version': 4},
#   {u'changeset': 24680841,
#    u'id': 101918,
#    u'lat': 51.5594877,
#    u'lon': -0.1969603,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2014-08-11T15:40:32Z',
#    u'type': u'node',
#    u'uid': 1016290,
#    u'user': u'ika-chan! UK',
#    u'version': 7},
#   {u'changeset': 50873724,
#    u'id': 101922,
#    u'lat': 51.5629312,
#    u'lon': -0.1972244,
#    u'tags': {u'highway': u'traffic_signals', u'traffic_signals': u'signal'},
#    u'timestamp': u'2017-08-06T01:53:40Z',
#    u'type': u'node',
#    u'uid': 5640166,
#    u'user': u'tintinrenaissance',
#    u'version': 4},
#   {u'changeset': 240226,
#    u'id': 101975,
#    u'lat': 51.546997,
#    u'lon': -0.158904,
#    u'tags': {u'created_by': u'YahooApplet 1.0'},
#    u'timestamp': u'2007-03-19T23:50:52Z',
#    u'type': u'node',
#    u'uid': 1611,
#    u'user': u'Harry Wood',
#    u'version': 1},
#   {u'changeset': 61514808,
#    u'id': 101977,
#    u'lat': 51.5456902,
#    u'lon': -0.1558806,
#    u'tags': {u'crossing_ref': u'pelican', u'highway': u'traffic_signals'},
#    u'timestamp': u'2018-08-09T22:36:16Z',
#    u'type': u'node',
#    u'uid': 322039,
#    u'user': u'MacLondon',
#    u'version': 5},
#   {u'changeset': 17607243,
#    u'id': 101984,
#    u'lat': 51.5237608,
#    u'lon': -0.1451285,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2013-08-31T18:18:15Z',
#    u'type': u'node',
#    u'uid': 1016290,
#    u'user': u'ika-chan! UK',
#    u'version': 5},
#   {u'changeset': 13420651,
#    u'id': 101990,
#    u'lat': 51.5205636,
#    u'lon': -0.1476994,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2012-10-09T01:09:27Z',
#    u'type': u'node',
#    u'uid': 900987,
#    u'user': u'Metanautics fixes',
#    u'version': 6},
#   {u'changeset': 13419434,
#    u'id': 101991,
#    u'lat': 51.5216539,
#    u'lon': -0.1481892,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2012-10-08T21:37:13Z',
#    u'type': u'node',
#    u'uid': 900987,
#    u'user': u'Metanautics fixes',
#    u'version': 7},
#   {u'changeset': 13420651,
#    u'id': 101993,
#    u'lat': 51.5203158,
#    u'lon': -0.1492251,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2012-10-09T01:09:27Z',
#    u'type': u'node',
#    u'uid': 900987,
#    u'user': u'Metanautics fixes',
#    u'version': 6},
#   {u'changeset': 13420651,
#    u'id': 102020,
#    u'lat': 51.5174352,
#    u'lon': -0.1554056,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2012-10-09T01:09:27Z',
#    u'type': u'node',
#    u'uid': 900987,
#    u'user': u'Metanautics fixes',
#    u'version': 7},
#   {u'changeset': 41225000,
#    u'id': 102025,
#    u'lat': 51.5194493,
#    u'lon': -0.1563176,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2016-08-03T22:02:30Z',
#    u'type': u'node',
#    u'uid': 17292,
#    u'user': u'jpennycook',
#    u'version': 8},
#   {u'changeset': 15695985,
#    u'id': 102035,
#    u'lat': 51.5152517,
#    u'lon': -0.1613431,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2013-04-12T00:22:11Z',
#    u'type': u'node',
#    u'uid': 1133848,
#    u'user': u'j00b',
#    u'version': 9},
#   {u'changeset': 13419771,
#    u'id': 102037,
#    u'lat': 51.5163695,
#    u'lon': -0.1617749,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2012-10-08T22:08:01Z',
#    u'type': u'node',
#    u'uid': 900987,
#    u'user': u'Metanautics fixes',
#    u'version': 9},
#   {u'changeset': 60884828,
#    u'id': 102044,
#    u'lat': 51.5125733,
#    u'lon': -0.1665523,
#    u'tags': {u'barrier': u'bollard',
#     u'bicycle': u'yes',
#     u'crossing': u'traffic_signals',
#     u'crossing_ref': u'pelican',
#     u'highway': u'traffic_signals'},
#    u'timestamp': u'2018-07-19T21:48:43Z',
#    u'type': u'node',
#    u'uid': 322039,
#    u'user': u'MacLondon',
#    u'version': 14},
#   {u'changeset': 33520848,
#    u'id': 102054,
#    u'lat': 51.513336,
#    u'lon': -0.1589742,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2015-08-23T09:47:31Z',
#    u'type': u'node',
#    u'uid': 2822392,
#    u'user': u'domdomegg',
#    u'version': 10},
#   {u'changeset': 13457665,
#    u'id': 102059,
#    u'lat': 51.5139368,
#    u'lon': -0.1680567,
#    u'tags': {u'direction': u'clockwise',
#     u'highway': u'mini_roundabout',
#     u'source': u'survey'},
#    u'timestamp': u'2012-10-11T18:06:26Z',
#    u'type': u'node',
#    u'uid': 900987,
#    u'user': u'Metanautics fixes',
#    u'version': 6},
#   {u'changeset': 25414814,
#    u'id': 102061,
#    u'lat': 51.5135895,
#    u'lon': -0.1715609,
#    u'tags': {u'direction': u'clockwise', u'highway': u'mini_roundabout'},
#    u'timestamp': u'2014-09-13T16:33:30Z',
#    u'type': u'node',
#    u'uid': 855535,
#    u'user': u"L'le Tom",
#    u'version': 8},
#   {u'changeset': 45537703,
#    u'id': 102072,
#    u'lat': 51.5115407,
#    u'lon': -0.1759837,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2017-01-27T01:30:34Z',
#    u'type': u'node',
#    u'uid': 322039,
#    u'user': u'MacLondon',
#    u'version': 12},
#   {u'changeset': 13297260,
#    u'id': 102085,
#    u'lat': 51.5102793,
#    u'lon': -0.1869255,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2012-09-29T14:25:28Z',
#    u'type': u'node',
#    u'uid': 900987,
#    u'user': u'Metanautics fixes',
#    u'version': 4},
#   {u'changeset': 61751050,
#    u'id': 102086,
#    u'lat': 51.5100761,
#    u'lon': -0.1898927,
#    u'tags': {u'crossing': u'traffic_signals',
#     u'crossing_ref': u'pelican',
#     u'highway': u'crossing'},
#    u'timestamp': u'2018-08-17T16:12:08Z',
#    u'type': u'node',
#    u'uid': 322039,
#    u'user': u'MacLondon',
#    u'version': 11},
#   {u'changeset': 13296438,
#    u'id': 102090,
#    u'lat': 51.5094769,
#    u'lon': -0.1941084,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2012-09-29T13:14:58Z',
#    u'type': u'node',
#    u'uid': 900987,
#    u'user': u'Metanautics fixes',
#    u'version': 4},
#   {u'changeset': 13296588,
#    u'id': 102100,
#    u'lat': 51.5019779,
#    u'lon': -0.1909015,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2012-09-29T13:29:30Z',
#    u'type': u'node',
#    u'uid': 900987,
#    u'user': u'Metanautics fixes',
#    u'version': 5},
#   {u'changeset': 32555844,
#    u'id': 104302,
#    u'lat': 51.5203627,
#    u'lon': -0.1303394,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2015-07-10T23:51:32Z',
#    u'type': u'node',
#    u'uid': 1679,
#    u'user': u'andrewpmk',
#    u'version': 10},
#   {u'changeset': 39615886,
#    u'id': 104315,
#    u'lat': 51.5181712,
#    u'lon': -0.1113596,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2016-05-27T23:36:40Z',
#    u'type': u'node',
#    u'uid': 82783,
#    u'user': u'Paul The Archivist',
#    u'version': 20},
#   {u'changeset': 35080405,
#    u'id': 104318,
#    u'lat': 51.5162346,
#    u'lon': -0.1019383,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2015-11-04T14:47:40Z',
#    u'type': u'node',
#    u'uid': 352985,
#    u'user': u'ecatmur',
#    u'version': 9},
#   {u'changeset': 9044505,
#    u'id': 104319,
#    u'lat': 51.5153556,
#    u'lon': -0.0987878,
#    u'tags': {u'crossing': u'traffic_signals', u'highway': u'crossing'},
#    u'timestamp': u'2011-08-17T06:39:15Z',
#    u'type': u'node',
#    u'uid': 87367,
#    u'user': u'marl',
#    u'version': 7},
#   {u'changeset': 36786298,
#    u'id': 104320,
#    u'lat': 51.5147196,
#    u'lon': -0.0968823,
#    u'tags': {u'crossing': u'traffic_signals', u'highway': u'crossing'},
#    u'timestamp': u'2016-01-24T23:12:37Z',
#    u'type': u'node',
#    u'uid': 1016290,
#    u'user': u'ika-chan! UK',
#    u'version': 10},
#   {u'changeset': 53711535,
#    u'id': 104322,
#    u'lat': 51.5138167,
#    u'lon': -0.0923314,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2017-11-12T12:35:18Z',
#    u'type': u'node',
#    u'uid': 24119,
#    u'user': u'Mauls',
#    u'version': 5},
#   {u'changeset': 24230287,
#    u'id': 104323,
#    u'lat': 51.5140621,
#    u'lon': -0.0751908,
#    u'tags': {u'crossing': u'traffic_signals',
#     u'crossing_ref': u'pelican',
#     u'highway': u'traffic_signals'},
#    u'timestamp': u'2014-07-18T21:35:29Z',
#    u'type': u'node',
#    u'uid': 1016290,
#    u'user': u'ika-chan! UK',
#    u'version': 6},
#   {u'changeset': 52126799,
#    u'id': 104327,
#    u'lat': 51.5151214,
#    u'lon': -0.0700803,
#    u'tags': {u'button_operated': u'yes',
#     u'crossing': u'traffic_signals',
#     u'crossing_ref': u'pelican',
#     u'highway': u'traffic_signals',
#     u'traffic_signals:sound': u'yes'},
#    u'timestamp': u'2017-09-17T20:23:26Z',
#    u'type': u'node',
#    u'uid': 541803,
#    u'user': u'antoineg',
#    u'version': 24},
#   {u'changeset': 34630729,
#    u'id': 104363,
#    u'lat': 51.4821518,
#    u'lon': -0.0088281,
#    u'tags': {u'crossing': u'yes', u'highway': u'traffic_signals'},
#    u'timestamp': u'2015-10-14T11:09:10Z',
#    u'type': u'node',
#    u'uid': 237926,
#    u'user': u'midlandsdave',
#    u'version': 8},
#   {u'changeset': 25354268,
#    u'id': 104387,
#    u'lat': 51.5006999,
#    u'lon': -0.1177675,
#    u'tags': {u'bicycle': u'yes',
#     u'crossing': u'traffic_signals',
#     u'crossing_ref': u'toucan',
#     u'highway': u'crossing'},
#    u'timestamp': u'2014-09-10T19:03:13Z',
#    u'type': u'node',
#    u'uid': 855535,
#    u'user': u"L'le Tom",
#    u'version': 9},
#   {u'changeset': 13296588,
#    u'id': 104401,
#    u'lat': 51.4990456,
#    u'lon': -0.1985966,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2012-09-29T13:29:30Z',
#    u'type': u'node',
#    u'uid': 900987,
#    u'user': u'Metanautics fixes',
#    u'version': 5},
#   {u'changeset': 35901564,
#    u'id': 105123,
#    u'lat': 51.460763,
#    u'lon': -0.0344163,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2015-12-12T02:21:52Z',
#    u'type': u'node',
#    u'uid': 493595,
#    u'user': u'Yorvik Prestigitator',
#    u'version': 2},
#   {u'changeset': 41105376,
#    u'id': 106213,
#    u'lat': 51.5256671,
#    u'lon': -0.1429838,
#    u'tags': {u'crossing': u'unmarked',
#     u'traffic_calming': u'table',
#     u'wheelchair': u'yes'},
#    u'timestamp': u'2016-07-29T10:59:13Z',
#    u'type': u'node',
#    u'uid': 214230,
#    u'user': u'London Nick',
#    u'version': 6},
#   {u'changeset': 517314,
#    u'id': 106752,
#    u'lat': 51.5144758,
#    u'lon': -0.03893,
#    u'tags': {u'created_by': u'YahooApplet 1.0'},
#    u'timestamp': u'2008-01-02T17:32:47Z',
#    u'type': u'node',
#    u'uid': 3762,
#    u'user': u'stev',
#    u'version': 2},
#   {u'changeset': 13599681,
#    u'id': 106761,
#    u'lat': 51.5167644,
#    u'lon': -0.0426257,
#    u'tags': {u'direction': u'clockwise', u'highway': u'mini_roundabout'},
#    u'timestamp': u'2012-10-22T23:53:59Z',
#    u'type': u'node',
#    u'uid': 28775,
#    u'user': u'StellanL',
#    u'version': 3},
#   {u'changeset': 411543,
#    u'id': 106764,
#    u'lat': 51.5153655,
#    u'lon': -0.0421249,
#    u'tags': {u'created_by': u'YahooApplet 1.0'},
#    u'timestamp': u'2007-09-10T22:30:52Z',
#    u'type': u'node',
#    u'uid': 3560,
#    u'user': u'Firefishy',
#    u'version': 1},
#   {u'changeset': 32689071,
#    u'id': 106767,
#    u'lat': 51.5148115,
#    u'lon': -0.0413646,
#    u'tags': {u'direction': u'clockwise', u'highway': u'mini_roundabout'},
#    u'timestamp': u'2015-07-17T05:54:16Z',
#    u'type': u'node',
#    u'uid': 534393,
#    u'user': u'Chris Baines',
#    u'version': 3},
#   {u'changeset': 1790007,
#    u'id': 106768,
#    u'lat': 51.5147746,
#    u'lon': -0.0404712,
#    u'tags': {u'direction': u'clockwise', u'highway': u'mini_roundabout'},
#    u'timestamp': u'2009-07-10T16:37:44Z',
#    u'type': u'node',
#    u'uid': 28024,
#    u'user': u'dbisping',
#    u'version': 6},
#   {u'changeset': 27504,
#    u'id': 106776,
#    u'lat': 51.5186803,
#    u'lon': -0.0460842,
#    u'tags': {u'created_by': u'YahooApplet 1.0'},
#    u'timestamp': u'2007-10-02T23:45:45Z',
#    u'type': u'node',
#    u'uid': 3762,
#    u'user': u'stev',
#    u'version': 1},
#   {u'changeset': 336593,
#    u'id': 106777,
#    u'lat': 51.5185127,
#    u'lon': -0.0462904,
#    u'tags': {u'created_by': u'YahooApplet 1.0'},
#    u'timestamp': u'2007-09-05T04:26:37Z',
#    u'type': u'node',
#    u'uid': 3560,
#    u'user': u'Firefishy',
#    u'version': 1},
#   {u'changeset': 39809,
#    u'id': 106778,
#    u'lat': 51.5158329,
#    u'lon': -0.0475542,
#    u'tags': {u'created_by': u'YahooApplet 1.0'},
#    u'timestamp': u'2007-05-03T23:26:42Z',
#    u'type': u'node',
#    u'uid': 1611,
#    u'user': u'Harry Wood',
#    u'version': 1},
#   {u'changeset': 336593,
#    u'id': 106789,
#    u'lat': 51.5172622,
#    u'lon': -0.0534053,
#    u'tags': {u'created_by': u'YahooApplet 1.0'},
#    u'timestamp': u'2007-09-05T04:26:39Z',
#    u'type': u'node',
#    u'uid': 3560,
#    u'user': u'Firefishy',
#    u'version': 1},
#   {u'changeset': 43113782,
#    u'id': 106801,
#    u'lat': 51.521072,
#    u'lon': -0.049981,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2016-10-24T04:01:32Z',
#    u'type': u'node',
#    u'uid': 322039,
#    u'user': u'MacLondon',
#    u'version': 9},
#   {u'changeset': 39809,
#    u'id': 106828,
#    u'lat': 51.5264731,
#    u'lon': -0.0707305,
#    u'tags': {u'created_by': u'YahooApplet 1.0'},
#    u'timestamp': u'2007-05-04T00:19:12Z',
#    u'type': u'node',
#    u'uid': 1611,
#    u'user': u'Harry Wood',
#    u'version': 1},
#   {u'changeset': 61643627,
#    u'id': 106830,
#    u'lat': 51.5284073,
#    u'lon': -0.0712484,
#    u'tags': {u'direction': u'clockwise', u'highway': u'mini_roundabout'},
#    u'timestamp': u'2018-08-14T03:14:49Z',
#    u'type': u'node',
#    u'uid': 322039,
#    u'user': u'MacLondon',
#    u'version': 6},
#   {u'changeset': 20036462,
#    u'id': 106832,
#    u'lat': 51.5284206,
#    u'lon': -0.0756372,
#    u'tags': {u'crossing': u'uncontrolled',
#     u'crossing_ref': u'zebra',
#     u'highway': u'crossing',
#     u'source': u'bing'},
#    u'timestamp': u'2014-01-16T16:29:23Z',
#    u'type': u'node',
#    u'uid': 178626,
#    u'user': u'Rovastar',
#    u'version': 13},
#   {u'changeset': 14896753,
#    u'id': 106839,
#    u'lat': 51.5271755,
#    u'lon': -0.0780586,
#    u'tags': {u'bicycle': u'no',
#     u'crossing': u'traffic_signals',
#     u'crossing_ref': u'pelican',
#     u'highway': u'traffic_signals',
#     u'segregated': u'no'},
#    u'timestamp': u'2013-02-03T14:05:07Z',
#    u'type': u'node',
#    u'uid': 1016290,
#    u'user': u'ika-chan! UK',
#    u'version': 15},
#   {u'changeset': 18779261,
#    u'id': 106848,
#    u'lat': 51.5202074,
#    u'lon': -0.0744628,
#    u'tags': {u'crossing': u'traffic_signals',
#     u'crossing_ref': u'pelican',
#     u'highway': u'traffic_signals'},
#    u'timestamp': u'2013-11-08T09:58:41Z',
#    u'type': u'node',
#    u'uid': 37137,
#    u'user': u'Derick Rethans',
#    u'version': 11},
#   {u'changeset': 74112,
#    u'id': 106869,
#    u'lat': 51.5327211,
#    u'lon': -0.0801329,
#    u'tags': {u'created_by': u'YahooApplet 1.0'},
#    u'timestamp': u'2007-05-31T04:29:27Z',
#    u'type': u'node',
#    u'uid': 4951,
#    u'user': u'PeterEastern',
#    u'version': 1},
#   {u'changeset': 13547786,
#    u'id': 106881,
#    u'lat': 51.5274199,
#    u'lon': -0.0888077,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2012-10-18T18:10:27Z',
#    u'type': u'node',
#    u'uid': 231451,
#    u'user': u'Kachkaev',
#    u'version': 14},
#   {u'changeset': 24450532,
#    u'id': 106904,
#    u'lat': 51.5195553,
#    u'lon': -0.0362329,
#    u'tags': {u'waterway': u'lock_gate'},
#    u'timestamp': u'2014-07-30T19:28:56Z',
#    u'type': u'node',
#    u'uid': 69984,
#    u'user': u'richardwest',
#    u'version': 4},
#   {u'changeset': 36987491,
#    u'id': 106927,
#    u'lat': 51.5107734,
#    u'lon': -0.0421115,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2016-02-03T22:25:07Z',
#    u'type': u'node',
#    u'uid': 125259,
#    u'user': u'abc26324',
#    u'version': 8},
#   {u'changeset': 6214,
#    u'id': 106954,
#    u'lat': 51.5153867,
#    u'lon': -0.0387415,
#    u'tags': {u'created_by': u'YahooApplet 1.0'},
#    u'timestamp': u'2007-04-04T16:36:01Z',
#    u'type': u'node',
#    u'uid': 7074,
#    u'user': u'NickF22',
#    u'version': 1},
#   {u'changeset': 336593,
#    u'id': 106968,
#    u'lat': 51.5136555,
#    u'lon': -0.0451607,
#    u'tags': {u'created_by': u'YahooApplet 1.0'},
#    u'timestamp': u'2007-09-05T05:35:41Z',
#    u'type': u'node',
#    u'uid': 3560,
#    u'user': u'Firefishy',
#    u'version': 1},
#   {u'changeset': 38155770,
#    u'id': 106969,
#    u'lat': 51.5110343,
#    u'lon': -0.0609863,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2016-03-30T01:11:47Z',
#    u'type': u'node',
#    u'uid': 322039,
#    u'user': u'MacLondon',
#    u'version': 6},
#   {u'changeset': 411543,
#    u'id': 106971,
#    u'lat': 51.5148996,
#    u'lon': -0.0452019,
#    u'tags': {u'created_by': u'YahooApplet 1.0'},
#    u'timestamp': u'2007-09-10T22:13:54Z',
#    u'type': u'node',
#    u'uid': 3560,
#    u'user': u'Firefishy',
#    u'version': 1},
#   {u'changeset': 626081,
#    u'id': 106988,
#    u'lat': 51.527895,
#    u'lon': -0.051117,
#    u'tags': {u'created_by': u'YahooApplet 1.0'},
#    u'timestamp': u'2007-11-25T23:01:50Z',
#    u'type': u'node',
#    u'uid': 3762,
#    u'user': u'stev',
#    u'version': 3},
#   {u'changeset': 50233832,
#    u'id': 107000,
#    u'lat': 51.5378391,
#    u'lon': -0.0608626,
#    u'tags': {u'crossing': u'uncontrolled',
#     u'crossing_ref': u'zebra',
#     u'highway': u'crossing',
#     u'name': u'crossing'},
#    u'timestamp': u'2017-07-12T15:36:33Z',
#    u'type': u'node',
#    u'uid': 322039,
#    u'user': u'MacLondon',
#    u'version': 11},
#   {u'changeset': 29666221,
#    u'id': 107002,
#    u'lat': 51.5384196,
#    u'lon': -0.0619246,
#    u'tags': {u'direction': u'clockwise', u'highway': u'mini_roundabout'},
#    u'timestamp': u'2015-03-22T21:15:40Z',
#    u'type': u'node',
#    u'uid': 481116,
#    u'user': u'bigalxyz123',
#    u'version': 5},
#   {u'changeset': 53656783,
#    u'id': 107035,
#    u'lat': 51.5377348,
#    u'lon': -0.0826996,
#    u'tags': {u'barrier': u'gate', u'foot': u'yes'},
#    u'timestamp': u'2017-11-10T04:57:52Z',
#    u'type': u'node',
#    u'uid': 322039,
#    u'user': u'MacLondon',
#    u'version': 5},
#   {u'changeset': 14333218,
#    u'id': 107039,
#    u'lat': 51.5417672,
#    u'lon': -0.0848702,
#    u'tags': {u'direction': u'clockwise', u'highway': u'mini_roundabout'},
#    u'timestamp': u'2012-12-19T17:14:13Z',
#    u'type': u'node',
#    u'uid': 1016290,
#    u'user': u'ika-chan! UK',
#    u'version': 12},
#   {u'changeset': 14527114,
#    u'id': 107043,
#    u'lat': 51.5406232,
#    u'lon': -0.0958341,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2013-01-04T15:17:40Z',
#    u'type': u'node',
#    u'uid': 1016290,
#    u'user': u'ika-chan! UK',
#    u'version': 5},
#   {u'changeset': 19339304,
#    u'id': 107096,
#    u'lat': 51.537779,
#    u'lon': -0.1069247,
#    u'tags': {u'traffic_calming': u'cushion'},
#    u'timestamp': u'2013-12-08T12:02:05Z',
#    u'type': u'node',
#    u'uid': 1016290,
#    u'user': u'ika-chan! UK',
#    u'version': 4},
#   {u'changeset': 26931950,
#    u'id': 107097,
#    u'lat': 51.5388635,
#    u'lon': -0.1072868,
#    u'tags': {u'traffic_calming': u'table'},
#    u'timestamp': u'2014-11-21T16:22:08Z',
#    u'type': u'node',
#    u'uid': 1016290,
#    u'user': u'ika-chan! UK',
#    u'version': 5},
#   {u'changeset': 854360,
#    u'id': 107103,
#    u'lat': 51.5386935,
#    u'lon': -0.1136792,
#    u'tags': {u'direction': u'clockwise', u'highway': u'mini_roundabout'},
#    u'timestamp': u'2009-03-24T20:26:49Z',
#    u'type': u'node',
#    u'uid': 61607,
#    u'user': u'skylark',
#    u'version': 4},
#   {u'changeset': 26332489,
#    u'id': 107108,
#    u'lat': 51.5347244,
#    u'lon': -0.0986673,
#    u'tags': {u'direction': u'clockwise', u'highway': u'mini_roundabout'},
#    u'timestamp': u'2014-10-26T00:00:37Z',
#    u'type': u'node',
#    u'uid': 1016290,
#    u'user': u'ika-chan! UK',
#    u'version': 11},
#   {u'changeset': 16600541,
#    u'id': 107115,
#    u'lat': 51.5172809,
#    u'lon': -0.029515,
#    u'tags': {u'cycleway': u'asl'},
#    u'timestamp': u'2013-06-18T08:56:54Z',
#    u'type': u'node',
#    u'uid': 1016290,
#    u'user': u'ika-chan! UK',
#    u'version': 3},
#   {u'changeset': 13266366,
#    u'id': 107240,
#    u'lat': 51.5077184,
#    u'lon': -0.0225607,
#    u'tags': {u'highway': u'crossing'},
#    u'timestamp': u'2012-09-27T00:20:24Z',
#    u'type': u'node',
#    u'uid': 24119,
#    u'user': u'Mauls',
#    u'version': 3},
#   {u'changeset': 22209,
#    u'id': 107242,
#    u'lat': 51.5069227,
#    u'lon': -0.0217652,
#    u'tags': {u'created_by': u'YahooApplet 1.0'},
#    u'timestamp': u'2007-04-22T21:58:36Z',
#    u'type': u'node',
#    u'uid': 736,
#    u'user': u'Steve Chilton',
#    u'version': 1},
#   {u'changeset': 792646,
#    u'id': 107296,
#    u'lat': 51.5576096,
#    u'lon': 0.0022148,
#    u'tags': {u'randomjunk_bot': u'reverted edit by FilipeOliveira on 2008-11-24T14:51:18+00:00'},
#    u'timestamp': u'2008-11-25T13:32:16Z',
#    u'type': u'node',
#    u'uid': 4049,
#    u'user': u'randomjunk',
#    u'version': 4},
#   {u'changeset': 18456023,
#    u'id': 107318,
#    u'lat': 51.5200969,
#    u'lon': -0.136436,
#    u'tags': {u'traffic_calming': u'table'},
#    u'timestamp': u'2013-10-20T17:47:52Z',
#    u'type': u'node',
#    u'uid': 855535,
#    u'user': u"L'le Tom",
#    u'version': 6},
#   {u'changeset': 22884690,
#    u'id': 107333,
#    u'lat': 51.5153055,
#    u'lon': -0.141966,
#    u'tags': {u'crossing': u'traffic_signals',
#     u'crossing_ref': u'pedestrian_scramble',
#     u'highway': u'crossing',
#     u'junction': u'crossroads',
#     u'name': u'Oxford Circus'},
#    u'timestamp': u'2014-06-12T08:14:31Z',
#    u'type': u'node',
#    u'uid': 1016290,
#    u'user': u'ika-chan! UK',
#    u'version': 16},
#   {u'changeset': 41701556,
#    u'id': 107352,
#    u'lat': 51.5208299,
#    u'lon': -0.1391027,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2016-08-25T21:32:23Z',
#    u'type': u'node',
#    u'uid': 82783,
#    u'user': u'Paul The Archivist',
#    u'version': 9},
#   {u'changeset': 52977291,
#    u'id': 107356,
#    u'lat': 51.534656,
#    u'lon': -0.0615757,
#    u'tags': {u'randomjunk_bot': u'reverted edit by FilipeOliveira on 2008-11-24T14:51:13+00:00'},
#    u'timestamp': u'2017-10-16T10:00:10Z',
#    u'type': u'node',
#    u'uid': 486343,
#    u'user': u'peregrination',
#    u'version': 6},
#   {u'changeset': 36538469,
#    u'id': 107357,
#    u'lat': 51.5351123,
#    u'lon': -0.062119,
#    u'tags': {u'randomjunk_bot': u'reverted edit by FilipeOliveira on 2008-11-24T14:51:14+00:00'},
#    u'timestamp': u'2016-01-12T21:08:14Z',
#    u'type': u'node',
#    u'uid': 481116,
#    u'user': u'bigalxyz123',
#    u'version': 4},
#   {u'changeset': 53544678,
#    u'id': 107358,
#    u'lat': 51.5349669,
#    u'lon': -0.0630174,
#    u'tags': {u'highway': u'traffic_signals', u'maxspeed': u'20 mph'},
#    u'timestamp': u'2017-11-06T04:38:28Z',
#    u'type': u'node',
#    u'uid': 322039,
#    u'user': u'MacLondon',
#    u'version': 11},
#   {u'changeset': 58724505,
#    u'id': 107362,
#    u'lat': 51.5308503,
#    u'lon': -0.0564283,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2018-05-06T08:56:43Z',
#    u'type': u'node',
#    u'uid': 82783,
#    u'user': u'Paul The Archivist',
#    u'version': 7},
#   {u'changeset': 58718139,
#    u'id': 107363,
#    u'lat': 51.5293391,
#    u'lon': -0.055868,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2018-05-05T23:18:10Z',
#    u'type': u'node',
#    u'uid': 82783,
#    u'user': u'Paul The Archivist',
#    u'version': 8},
#   {u'changeset': 61610511,
#    u'id': 107369,
#    u'lat': 51.5328316,
#    u'lon': -0.041321,
#    u'tags': {u'crossing': u'uncontrolled',
#     u'crossing:island': u'yes',
#     u'crossing_ref': u'zebra',
#     u'highway': u'crossing'},
#    u'timestamp': u'2018-08-13T03:54:56Z',
#    u'type': u'node',
#    u'uid': 322039,
#    u'user': u'MacLondon',
#    u'version': 13},
#   {u'changeset': 59828208,
#    u'id': 107376,
#    u'lat': 51.5298796,
#    u'lon': -0.0393194,
#    u'tags': {u'randomjunk_bot': u'reverted edit by FilipeOliveira on 2008-11-24T14:51:15+00:00'},
#    u'timestamp': u'2018-06-14T00:36:36Z',
#    u'type': u'node',
#    u'uid': 82783,
#    u'user': u'Paul The Archivist',
#    u'version': 5},
#   {u'changeset': 30208966,
#    u'id': 107392,
#    u'lat': 51.5466851,
#    u'lon': -0.0550308,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2015-04-14T11:21:35Z',
#    u'type': u'node',
#    u'uid': 1016290,
#    u'user': u'ika-chan! UK',
#    u'version': 6},
#   {u'changeset': 17527964,
#    u'id': 107393,
#    u'lat': 51.5480593,
#    u'lon': -0.0476754,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2013-08-27T01:56:21Z',
#    u'type': u'node',
#    u'uid': 322039,
#    u'user': u'MacLondon',
#    u'version': 2},
#   {u'changeset': 17527964,
#    u'id': 107402,
#    u'lat': 51.5513377,
#    u'lon': -0.0436589,
#    u'tags': {u'traffic_calming': u'yes'},
#    u'timestamp': u'2013-08-27T01:56:21Z',
#    u'type': u'node',
#    u'uid': 322039,
#    u'user': u'MacLondon',
#    u'version': 4},
#   {u'changeset': 792646,
#    u'id': 107408,
#    u'lat': 51.5597592,
#    u'lon': -0.0477237,
#    u'tags': {u'randomjunk_bot': u'reverted edit by FilipeOliveira on 2008-11-24T14:51:14+00:00'},
#    u'timestamp': u'2008-11-25T13:32:22Z',
#    u'type': u'node',
#    u'uid': 4049,
#    u'user': u'randomjunk',
#    u'version': 4},
#   {u'changeset': 792646,
#    u'id': 107409,
#    u'lat': 51.5607528,
#    u'lon': -0.0489466,
#    u'tags': {u'highway': u'traffic_signals',
#     u'randomjunk_bot': u'reverted edit by FilipeOliveira on 2008-11-24T14:51:15+00:00'},
#    u'timestamp': u'2008-11-25T13:32:23Z',
#    u'type': u'node',
#    u'uid': 4049,
#    u'user': u'randomjunk',
#    u'version': 4},
#   {u'changeset': 14112622,
#    u'id': 107439,
#    u'lat': 51.5110117,
#    u'lon': -0.0541927,
#    u'tags': {u'highway': u'crossing'},
#    u'timestamp': u'2012-12-01T14:56:21Z',
#    u'type': u'node',
#    u'uid': 348243,
#    u'user': u'andreamar',
#    u'version': 5},
#   {u'changeset': 17807648,
#    u'id': 107442,
#    u'lat': 51.5097127,
#    u'lon': -0.0569513,
#    u'tags': {u'highway': u'crossing'},
#    u'timestamp': u'2013-09-12T21:05:29Z',
#    u'type': u'node',
#    u'uid': 1016290,
#    u'user': u'ika-chan! UK',
#    u'version': 11},
#   {u'changeset': 432083,
#    u'id': 107454,
#    u'lat': 51.5135354,
#    u'lon': -0.0611721,
#    u'tags': {u'created_by': u'YahooApplet 1.0'},
#    u'timestamp': u'2008-05-12T09:07:42Z',
#    u'type': u'node',
#    u'uid': 21931,
#    u'user': u'amm',
#    u'version': 2},
#   {u'changeset': 35610993,
#    u'id': 107455,
#    u'lat': 51.5132358,
#    u'lon': -0.0615118,
#    u'tags': {u'randomjunk_bot': u'reverted edit by FilipeOliveira on 2008-11-26T17:23:52+00:00'},
#    u'timestamp': u'2015-11-27T13:03:54Z',
#    u'type': u'node',
#    u'uid': 2969887,
#    u'user': u'eastender',
#    u'version': 4},
#   {u'changeset': 800592,
#    u'id': 107456,
#    u'lat': 51.5128426,
#    u'lon': -0.0614086,
#    u'tags': {u'created_by': u'YahooApplet 1.0',
#     u'randomjunk_bot': u'reverted edit by FilipeOliveira on 2008-11-26T17:23:52+00:00'},
#    u'timestamp': u'2008-11-26T23:00:05Z',
#    u'type': u'node',
#    u'uid': 4049,
#    u'user': u'randomjunk',
#    u'version': 3},
#   {u'changeset': 2737903,
#    u'id': 107458,
#    u'lat': 51.510173,
#    u'lon': -0.060722,
#    u'tags': {u'randomjunk_bot': u'reverted edit by FilipeOliveira on 2008-11-26T17:24:32+00:00'},
#    u'timestamp': u'2009-10-04T16:23:51Z',
#    u'type': u'node',
#    u'uid': 181546,
#    u'user': u'Richard A',
#    u'version': 4},
#   {u'changeset': 800592,
#    u'id': 107465,
#    u'lat': 51.5053444,
#    u'lon': -0.0589367,
#    u'tags': {u'randomjunk_bot': u'reverted edit by FilipeOliveira on 2008-11-26T17:23:58+00:00'},
#    u'timestamp': u'2008-11-26T23:00:06Z',
#    u'type': u'node',
#    u'uid': 4049,
#    u'user': u'randomjunk',
#    u'version': 3},
#   {u'changeset': 800592,
#    u'id': 107468,
#    u'lat': 51.5052658,
#    u'lon': -0.061352,
#    u'tags': {u'randomjunk_bot': u'reverted edit by FilipeOliveira on 2008-11-26T17:23:58+00:00'},
#    u'timestamp': u'2008-11-26T23:00:06Z',
#    u'type': u'node',
#    u'uid': 4049,
#    u'user': u'randomjunk',
#    u'version': 4},
#   {u'changeset': 800592,
#    u'id': 107469,
#    u'lat': 51.5112076,
#    u'lon': -0.0631359,
#    u'tags': {u'randomjunk_bot': u'reverted edit by FilipeOliveira on 2008-11-26T17:23:58+00:00'},
#    u'timestamp': u'2008-11-26T23:00:07Z',
#    u'type': u'node',
#    u'uid': 4049,
#    u'user': u'randomjunk',
#    u'version': 3},
#   {u'changeset': 40123251,
#    u'id': 107470,
#    u'lat': 51.5041411,
#    u'lon': -0.0613979,
#    u'tags': {u'randomjunk_bot': u'reverted edit by FilipeOliveira on 2008-11-26T17:23:57+00:00'},
#    u'timestamp': u'2016-06-18T20:23:29Z',
#    u'type': u'node',
#    u'uid': 486343,
#    u'user': u'peregrination',
#    u'version': 4},
#   {u'changeset': 36765446,
#    u'id': 107471,
#    u'lat': 51.5027056,
#    u'lon': -0.0486042,
#    u'tags': {u'randomjunk_bot': u'reverted edit by FilipeOliveira on 2008-11-26T17:23:57+00:00'},
#    u'timestamp': u'2016-01-23T20:46:47Z',
#    u'type': u'node',
#    u'uid': 12503,
#    u'user': u'Paul Todd',
#    u'version': 5},
#   {u'changeset': 36514698,
#    u'id': 107474,
#    u'lat': 51.505656,
#    u'lon': -0.040171,
#    u'tags': {u'highway': u'crossing'},
#    u'timestamp': u'2016-01-11T22:31:36Z',
#    u'type': u'node',
#    u'uid': 12503,
#    u'user': u'Paul Todd',
#    u'version': 2},
#   {u'changeset': 49014456,
#    u'id': 107488,
#    u'lat': 51.5110211,
#    u'lon': -0.0159447,
#    u'tags': {u'bicycle': u'yes',
#     u'crossing': u'traffic_signals',
#     u'highway': u'crossing'},
#    u'timestamp': u'2017-05-27T00:32:00Z',
#    u'type': u'node',
#    u'uid': 322039,
#    u'user': u'MacLondon',
#    u'version': 6},
#   {u'changeset': 14903845,
#    u'id': 107503,
#    u'lat': 51.511339,
#    u'lon': -0.0107528,
#    u'tags': {u'highway': u'crossing'},
#    u'timestamp': u'2013-02-03T23:05:44Z',
#    u'type': u'node',
#    u'uid': 1016290,
#    u'user': u'ika-chan! UK',
#    u'version': 6},
#   {u'changeset': 550796,
#    u'id': 107550,
#    u'lat': 51.4930877,
#    u'lon': -0.0469814,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2008-07-20T19:05:35Z',
#    u'type': u'node',
#    u'uid': 6871,
#    u'user': u'smsm1',
#    u'version': 3},
#   {u'changeset': 42361336,
#    u'id': 107551,
#    u'lat': 51.493818,
#    u'lon': -0.0483055,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2016-09-22T22:35:15Z',
#    u'type': u'node',
#    u'uid': 125259,
#    u'user': u'abc26324',
#    u'version': 10},
#   {u'changeset': 62181279,
#    u'id': 107557,
#    u'lat': 51.4995342,
#    u'lon': -0.0544337,
#    u'tags': {u'bus': u'yes',
#     u'local_ref': u'X',
#     u'name': u'Rotherhithe Tunnel',
#     u'public_transport': u'stop_position'},
#    u'timestamp': u'2018-08-31T18:38:40Z',
#    u'type': u'node',
#    u'uid': 2969887,
#    u'user': u'eastender',
#    u'version': 11},
#   {u'changeset': 25805268,
#    u'id': 107566,
#    u'lat': 51.502396,
#    u'lon': -0.0774673,
#    u'tags': {u'crossing': u'controlled', u'highway': u'traffic_signals'},
#    u'timestamp': u'2014-10-02T08:31:07Z',
#    u'type': u'node',
#    u'uid': 346,
#    u'user': u'Tom Chance',
#    u'version': 8},
#   {u'changeset': 18930316,
#    u'id': 107574,
#    u'lat': 51.5091314,
#    u'lon': -0.0738921,
#    u'tags': {u'crossing': u'traffic_signals',
#     u'crossing_ref': u'pelican',
#     u'highway': u'crossing',
#     u'kerb': u'lowered',
#     u'sloped_curb': u'yes'},
#    u'timestamp': u'2013-11-16T10:40:29Z',
#    u'type': u'node',
#    u'uid': 17292,
#    u'user': u'jpennycook',
#    u'version': 9},
#   {u'changeset': 29222958,
#    u'id': 107587,
#    u'lat': 51.5134098,
#    u'lon': -0.0840742,
#    u'tags': {u'crossing': u'traffic_signals',
#     u'crossing_ref': u'pelican',
#     u'highway': u'traffic_signals'},
#    u'timestamp': u'2015-03-03T13:39:18Z',
#    u'type': u'node',
#    u'uid': 1016290,
#    u'user': u'ika-chan! UK',
#    u'version': 9},
#   {u'changeset': 61450496,
#    u'id': 107606,
#    u'lat': 51.5131109,
#    u'lon': -0.0777973,
#    u'tags': {u'crossing': u'traffic_signals',
#     u'crossing_ref': u'pelican',
#     u'highway': u'crossing'},
#    u'timestamp': u'2018-08-08T01:14:16Z',
#    u'type': u'node',
#    u'uid': 322039,
#    u'user': u'MacLondon',
#    u'version': 8},
#   {u'changeset': 18739287,
#    u'id': 107608,
#    u'lat': 51.5149809,
#    u'lon': -0.0684543,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2013-11-05T23:32:42Z',
#    u'type': u'node',
#    u'uid': 1016290,
#    u'user': u'ika-chan! UK',
#    u'version': 21},
#   {u'changeset': 52544468,
#    u'id': 107637,
#    u'lat': 51.5116965,
#    u'lon': -0.0907237,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2017-10-01T18:27:20Z',
#    u'type': u'node',
#    u'uid': 82783,
#    u'user': u'Paul The Archivist',
#    u'version': 11},
#   {u'changeset': 48327020,
#    u'id': 107639,
#    u'lat': 51.5121405,
#    u'lon': -0.0926958,
#    u'tags': {u'crossing': u'traffic_signals',
#     u'crossing_ref': u'toucan',
#     u'highway': u'crossing'},
#    u'timestamp': u'2017-05-02T08:02:26Z',
#    u'type': u'node',
#    u'uid': 352985,
#    u'user': u'ecatmur',
#    u'version': 10},
#   {u'changeset': 13303230,
#    u'id': 107645,
#    u'lat': 51.5128981,
#    u'lon': -0.0964705,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2012-09-29T22:50:37Z',
#    u'type': u'node',
#    u'uid': 900987,
#    u'user': u'Metanautics fixes',
#    u'version': 12},
#   {u'changeset': 16984091,
#    u'id': 107651,
#    u'lat': 51.5132991,
#    u'lon': -0.0893107,
#    u'tags': {u'crossing': u'traffic_signals', u'highway': u'crossing'},
#    u'timestamp': u'2013-07-17T09:14:43Z',
#    u'type': u'node',
#    u'uid': 1016290,
#    u'user': u'ika-chan! UK',
#    u'version': 11},
#   {u'changeset': 61747411,
#    u'id': 107652,
#    u'lat': 51.5135191,
#    u'lon': -0.0890667,
#    u'tags': {u'crossing': u'traffic_signals', u'highway': u'crossing'},
#    u'timestamp': u'2018-08-17T13:53:15Z',
#    u'type': u'node',
#    u'uid': 7532683,
#    u'user': u'dendreier',
#    u'version': 8},
#   {u'changeset': 50735412,
#    u'id': 107693,
#    u'lat': 51.5141277,
#    u'lon': -0.1094254,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2017-07-31T23:28:00Z',
#    u'type': u'node',
#    u'uid': 352985,
#    u'user': u'ecatmur',
#    u'version': 8},
#   {u'changeset': 24784723,
#    u'id': 107699,
#    u'lat': 51.5109203,
#    u'lon': -0.1135266,
#    u'tags': {u'crossing': u'traffic_signals', u'highway': u'crossing'},
#    u'timestamp': u'2014-08-16T11:08:35Z',
#    u'type': u'node',
#    u'uid': 855535,
#    u'user': u"L'le Tom",
#    u'version': 11},
#   {u'changeset': 13303688,
#    u'id': 107708,
#    u'lat': 51.5129232,
#    u'lon': -0.1136998,
#    u'tags': {u'randomjunk_bot': u'reverted edit by FilipeOliveira on 2008-11-26T17:23:44+00:00'},
#    u'timestamp': u'2012-09-30T00:35:37Z',
#    u'type': u'node',
#    u'uid': 900987,
#    u'user': u'Metanautics fixes',
#    u'version': 6},
#   {u'changeset': 13303688,
#    u'id': 107714,
#    u'lat': 51.5124406,
#    u'lon': -0.1157494,
#    u'tags': {u'randomjunk_bot': u'reverted edit by FilipeOliveira on 2008-11-26T17:24:24+00:00'},
#    u'timestamp': u'2012-09-30T00:35:37Z',
#    u'type': u'node',
#    u'uid': 900987,
#    u'user': u'Metanautics fixes',
#    u'version': 6},
#   {u'changeset': 13582465,
#    u'id': 107728,
#    u'lat': 51.5057051,
#    u'lon': -0.1180919,
#    u'tags': {u'randomjunk_bot': u'reverted edit by FilipeOliveira on 2008-11-26T17:25:09+00:00'},
#    u'timestamp': u'2012-10-21T16:54:28Z',
#    u'type': u'node',
#    u'uid': 12671,
#    u'user': u'sladen',
#    u'version': 12},
#   {u'changeset': 13420110,
#    u'id': 107742,
#    u'lat': 51.5023686,
#    u'lon': -0.116457,
#    u'tags': {u'randomjunk_bot': u'reverted edit by FilipeOliveira on 2008-11-26T17:23:43+00:00'},
#    u'timestamp': u'2012-10-08T22:54:13Z',
#    u'type': u'node',
#    u'uid': 900987,
#    u'user': u'Metanautics fixes',
#    u'version': 7},
#   {u'changeset': 55916773,
#    u'id': 107746,
#    u'lat': 51.5004152,
#    u'lon': -0.116559,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2018-01-31T03:39:21Z',
#    u'type': u'node',
#    u'uid': 322039,
#    u'user': u'MacLondon',
#    u'version': 13},
#   {u'changeset': 21190899,
#    u'id': 107770,
#    u'lat': 51.507179,
#    u'lon': -0.1275661,
#    u'tags': {u'crossing': u'traffic_signals',
#     u'crossing_ref': u'pelican',
#     u'foot': u'yes',
#     u'highway': u'crossing',
#     u'segregated': u'no'},
#    u'timestamp': u'2014-03-19T12:36:57Z',
#    u'type': u'node',
#    u'uid': 125259,
#    u'user': u'abc26324',
#    u'version': 9},
#   {u'changeset': 25789589,
#    u'id': 107773,
#    u'lat': 51.5075061,
#    u'lon': -0.1273553,
#    u'tags': {u'crossing': u'traffic_signals',
#     u'crossing_ref': u'pelican',
#     u'foot': u'yes',
#     u'highway': u'crossing'},
#    u'timestamp': u'2014-10-01T13:05:51Z',
#    u'type': u'node',
#    u'uid': 145231,
#    u'user': u'woodpeck_repair',
#    u'version': 13},
#   {u'changeset': 61743724,
#    u'id': 107775,
#    u'lat': 51.5073219,
#    u'lon': -0.1276474,
#    u'tags': {u'admin_level': u'2',
#     u'capital': u'yes',
#     u'ele': u'15',
#     u'is_capital': u'country',
#     u'is_in': u'England, United Kingdom, UK, Great Britain, Europe',
#     u'is_in:continent': u'Europe',
#     u'is_in:country': u'United Kingdom',
#     u'is_in:country_code': u'GB',
#     u'is_in:iso_3166_2': u'GB-ENG',
#     u'name': u'London',
#     u'name:ab': u'\u041b\u043e\u043d\u0434\u0430\u043d',
#     u'name:af': u'Londen',
#     u'name:am': u'\u1208\u1295\u12f0\u1295',
#     u'name:an': u'Londres',
#     u'name:ang': u'Lunden',
#     u'name:ar': u'\u0644\u0646\u062f\u0646',
#     u'name:arc': u'\u0720\u0718\u0722\u0715\u0718\u0722',
#     u'name:arz': u'\u0644\u0646\u062f\u0646',
#     u'name:ast': u'Londres',
#     u'name:ba': u'\u041b\u043e\u043d\u0434\u043e\u043d',
#     u'name:bat-smg': u'Londons',
#     u'name:bcl': u'Londres',
#     u'name:be': u'\u041b\u043e\u043d\u0434\u0430\u043d',
#     u'name:be-tarask': u'\u041b\u0451\u043d\u0434\u0430\u043d',
#     u'name:bg': u'\u041b\u043e\u043d\u0434\u043e\u043d',
#     u'name:bn': u'\u09b2\u09a8\u09cd\u09a1\u09a8',
#     u'name:bo': u'\u0f63\u0f7c\u0f53\u0f0b\u0f4a\u0f7c\u0f53\u0f0d',
#     u'name:br': u'Londrez',
#     u'name:ca': u'Londres',
#     u'name:cdo': u'L\xf9ng-d\u016dng',
#     u'name:ckb': u'\u0644\u06d5\u0646\u062f\u06d5\u0646',
#     u'name:co': u'Londra',
#     u'name:cs': u'Lond\xfdn',
#     u'name:cu': u'\u041b\u043e\u043d\u0434\u043e\u043d\u044a',
#     u'name:cv': u'\u041b\u043e\u043d\u0434\u043e\u043d',
#     u'name:cy': u'Llundain',
#     u'name:de': u'London',
#     u'name:diq': u'Londra',
#     u'name:el': u'\u039b\u03bf\u03bd\u03b4\u03af\u03bd\u03bf',
#     u'name:eml': u'L\xf2ndra',
#     u'name:en': u'London',
#     u'name:eo': u'Londono',
#     u'name:es': u'Londres',
#     u'name:eu': u'Londres',
#     u'name:ext': u'Londri',
#     u'name:fa': u'\u0644\u0646\u062f\u0646',
#     u'name:fi': u'Lontoo',
#     u'name:fr': u'Londres',
#     u'name:frp': u'Londres',
#     u'name:fy': u'Londen',
#     u'name:ga': u'Londain',
#     u'name:gan': u'\u502b\u6566',
#     u'name:gd': u'Lunnainn',
#     u'name:gl': u'Londres - London',
#     u'name:gn': u'Londye',
#     u'name:gu': u'\u0ab2\u0a82\u0aa1\u0aa8',
#     u'name:gv': u'Lunnin',
#     u'name:haw': u'L\u0101kana',
#     u'name:he': u'\u05dc\u05d5\u05e0\u05d3\u05d5\u05df',
#     u'name:hi': u'\u0932\u0902\u0926\u0928',
#     u'name:ht': u'Lonn',
#     u'name:hu': u'London',
#     u'name:hy': u'\u053c\u0578\u0576\u0564\u0578\u0576',
#     u'name:ilo': u'Londres',
#     u'name:is': u'Lund\xfanir',
#     u'name:it': u'Londra',
#     u'name:ja': u'\u30ed\u30f3\u30c9\u30f3',
#     u'name:jbo': u'london',
#     u'name:ka': u'\u10da\u10dd\u10dc\u10d3\u10dd\u10dc\u10d8',
#     u'name:kk': u'\u041b\u043e\u043d\u0434\u043e\u043d',
#     u'name:kn': u'\u0cb2\u0c82\u0ca1\u0ca8\u0ccd',
#     u'name:ko': u'\ub7f0\ub358',
#     u'name:koi': u'\u041b\u043e\u043d\u0434\u043e\u043d',
#     u'name:krc': u'\u041b\u043e\u043d\u0434\u043e\u043d',
#     u'name:ku': u'London',
#     u'name:kv': u'\u041b\u043e\u043d\u0434\u043e\u043d',
#     u'name:kw': u'Loundres',
#     u'name:ky': u'\u041b\u043e\u043d\u0434\u043e\u043d',
#     u'name:la': u'Londinium',
#     u'name:lad': u'Londra',
#     u'name:lbe': u'\u041b\u043e\u043d\u0434\u043e\u043d',
#     u'name:lez': u'\u041b\u043e\u043d\u0434\u043e\u043d',
#     u'name:li': u'Londe',
#     u'name:lij': u'Londra',
#     u'name:lmo': u'Lundra',
#     u'name:ln': u'Londoni',
#     u'name:lo': u'\u0ea5\u0ead\u0e99\u0e94\u0ead\u0e99',
#     u'name:lt': u'Londonas',
#     u'name:lv': u'Londona',
#     u'name:mhr': u'\u041b\u043e\u043d\u0434\u043e\u043d',
#     u'name:mi': u'R\u0101nana',
#     u'name:mk': u'\u041b\u043e\u043d\u0434\u043e\u043d',
#     u'name:ml': u'\u0d32\u0d23\u0d4d\u0d1f\u0d7b',
#     u'name:mn': u'\u041b\u043e\u043d\u0434\u043e\u043d',
#     u'name:mr': u'\u0932\u0902\u0921\u0928',
#     u'name:mrj': u'\u041b\u043e\u043d\u0434\u043e\u043d',
#     u'name:mt': u'Londra',
#     u'name:mwl': u'Londres',
#     u'name:my': u'\u101c\u1014\u103a\u1012\u1014\u103a\u1019\u103c\u102d\u102f\u1037',
#     u'name:mzn': u'\u0644\u0646\u062f\u0646',
#     u'name:nah': u'Londres',
#     u'name:nap': u'Londra',
#     u'name:nds-nl': u'Londen',
#     u'name:ne': u'\u0932\u0923\u094d\u0921\u0928',
#     u'name:new': u'\u0932\u0923\u094d\u0921\u0928',
#     u'name:nl': u'Londen',
#     u'name:no': u'London',
#     u'name:nrm': u'Londres',
#     u'name:oc': u'Londres',
#     u'name:or': u'\u0b32\u0b23\u0b4d\u0b21\u0b28',
#     u'name:os': u'\u041b\u043e\u043d\u0434\u043e\u043d',
#     u'name:pcd': u'Londe',
#     u'name:pl': u'Londyn',
#     u'name:pms': u'Londra',
#     u'name:pnb': u'\u0644\u0646\u062f\u0646',
#     u'name:pnt': u'\u039b\u03bf\u03bd\u03b4\u03af\u03bd\u03bf',
#     u'name:ps': u'\u0644\u0646\u062f\u0646',
#     u'name:pt': u'Londres',
#     u'name:rm': u'Londra',
#     u'name:ro': u'Londra',
#     u'name:roa-rup': u'Londra',
#     u'name:roa-tara': u'Londre',
#     u'name:ru': u'\u041b\u043e\u043d\u0434\u043e\u043d',
#     u'name:rue': u'\u041b\u043e\u043d\u0434\u043e\u043d',
#     u'name:sa': u'\u0932\u0928\u094d\u0921\u0928\u094d',
#     u'name:sah': u'\u041b\u043e\u043d\u0434\u043e\u043d',
#     u'name:sc': u'Londra',
#     u'name:scn': u'Londra',
#     u'name:sco': u'Lunnon',
#     u'name:si': u'\u0dbd\u0db1\u0dca\u0da9\u0db1\u0dca',
#     u'name:sk': u'Lond\xfdn',
#     u'name:sq': u'Londra',
#     u'name:sr': u'\u041b\u043e\u043d\u0434\u043e\u043d',
#     u'name:sv': u'London',
#     u'name:szl': u'L\u016fnd\u016fn',
#     u'name:ta': u'\u0b87\u0bb2\u0ba3\u0bcd\u0b9f\u0ba9\u0bcd',
#     u'name:te': u'\u0c32\u0c02\u0c21\u0c28\u0c4d',
#     u'name:tet': u'Londres',
#     u'name:tg': u'\u041b\u043e\u043d\u0434\u043e\u043d',
#     u'name:th': u'\u0e25\u0e2d\u0e19\u0e14\u0e2d\u0e19',
#     u'name:tl': u'Londres',
#     u'name:tpi': u'Landen',
#     u'name:tr': u'Londra',
#     u'name:tt': u'\u041b\u043e\u043d\u0434\u043e\u043d',
#     u'name:tzl': u'Londra',
#     u'name:udm': u'\u041b\u043e\u043d\u0434\u043e\u043d',
#     u'name:uk': u'\u041b\u043e\u043d\u0434\u043e\u043d',
#     u'name:ur': u'\u0644\u0646\u062f\u0646',
#     u'name:vec': u'\u0141ondra',
#     u'name:vi': u'Lu\xe2n \u0110\xf4n',
#     u'name:vls': u'Londn',
#     u'name:wo': u'Londar',
#     u'name:wuu': u'\u4f26\u6566',
#     u'name:xmf': u'\u10da\u10dd\u10dc\u10d3\u10dd\u10dc\u10d8',
#     u'name:yi': u'\u05dc\u05d0\u05e0\u05d3\u05d0\u05df',
#     u'name:yo': u'L\u1ecdnd\u1ecdnu',
#     u'name:yue': u'\u502b\u6566',
#     u'name:zea': u'Londen',
#     u'name:zh': u'\u502b\u6566',
#     u'name:zh-classical': u'\u502b\u6566',
#     u'name:zh-simplified': u'\u4f26\u6566',
#     u'name:zh-traditional': u'\u502b\u6566',
#     u'name:zh_pinyin': u'L\xfand\u016bn',
#     u'name:zu': u'ILondon',
#     u'note': u'Centre of London officially at the former location of the Charing Cross, now the Charles I statue, near Trafalgar Square.',
#     u'place': u'city',
#     u'population': u'8416535',
#     u'website': u'http://www.london.gov.uk',
#     u'wikidata': u'Q84',
#     u'wikimedia_commons': u'Category:London',
#     u'wikipedia': u'en:London'},
#    u'timestamp': u'2018-08-17T11:49:47Z',
#    u'type': u'node',
#    u'uid': 1242214,
#    u'user': u'jc86035',
#    u'version': 80},
#   {u'changeset': 17858148,
#    u'id': 107790,
#    u'lat': 51.511322,
#    u'lon': -0.1283895,
#    u'tags': {u'highway': u'traffic_signals',
#     u'randomjunk_bot': u'reverted edit by FilipeOliveira on 2008-11-26T17:23:44+00:00'},
#    u'timestamp': u'2013-09-15T21:06:46Z',
#    u'type': u'node',
#    u'uid': 286584,
#    u'user': u'Firefishy_repair',
#    u'version': 8},
#   {u'changeset': 61386783,
#    u'id': 107792,
#    u'lat': 51.513281,
#    u'lon': -0.1290796,
#    u'tags': {u'crossing': u'traffic_signals',
#     u'crossing_ref': u'pelican',
#     u'highway': u'crossing',
#     u'junction': u'crossroads',
#     u'name': u'Cambridge Circus',
#     u'wikidata': u'Q2934700',
#     u'wikipedia': u'en:Cambridge Circus, London'},
#    u'timestamp': u'2018-08-06T01:01:47Z',
#    u'type': u'node',
#    u'uid': 322039,
#    u'user': u'MacLondon',
#    u'version': 19},
#   {u'changeset': 56103689,
#    u'id': 107805,
#    u'lat': 51.5127816,
#    u'lon': -0.129931,
#    u'tags': {u'note': u'continue cycle route to Covent Garden'},
#    u'timestamp': u'2018-02-06T03:17:17Z',
#    u'type': u'node',
#    u'uid': 2055614,
#    u'user': u'Mikhail1412',
#    u'version': 8},
#   {u'changeset': 57257941,
#    u'id': 107809,
#    u'lat': 51.5114964,
#    u'lon': -0.1330266,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2018-03-17T04:03:20Z',
#    u'type': u'node',
#    u'uid': 2055614,
#    u'user': u'Mikhail1412',
#    u'version': 9},
#   {u'changeset': 54032412,
#    u'id': 107813,
#    u'lat': 51.5106947,
#    u'lon': -0.1339402,
#    u'tags': {u'crossing': u'traffic_signals',
#     u'crossing_ref': u'pelican',
#     u'highway': u'traffic_signals'},
# ...
#    u'uid': 7769212,
#    u'user': u'Gerard Butler',
#    u'version': 4},
#   {u'changeset': 223011,
#    u'id': 282258,
#    u'lat': 51.6006136,
#    u'lon': -0.2674102,
#    u'tags': {u'created_by': u'YahooApplet 1.0',
#     u'highway': u'traffic_signals'},
#    u'timestamp': u'2007-10-17T21:51:08Z',
#    u'type': u'node',
#    u'uid': 508,
#    u'user': u'Welshie',
#    u'version': 3},
#   {u'changeset': 13174865,
#    u'id': 282669,
#    u'lat': 51.5686736,
#    u'lon': -0.2077596,
#    u'tags': {u'highway': u'crossing'},
#    u'timestamp': u'2012-09-19T19:44:14Z',
#    u'type': u'node',
#    u'uid': 6871,
#    u'user': u'smsm1',
#    u'version': 2},
#   {u'changeset': 33782064,
#    u'id': 282670,
#    u'lat': 51.5668052,
#    u'lon': -0.2064164,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2015-09-03T20:44:04Z',
#    u'type': u'node',
#    u'uid': 1016290,
#    u'user': u'ika-chan! UK',
#    u'version': 3},
#   {u'changeset': 24680841,
#    u'id': 282688,
#    u'lat': 51.5594296,
#    u'lon': -0.1971897,
#    u'tags': {u'crossing': u'traffic_signals',
#     u'crossing_ref': u'pelican',
#     u'highway': u'crossing'},
#    u'timestamp': u'2014-08-11T15:40:32Z',
#    u'type': u'node',
#    u'uid': 1016290,
#    u'user': u'ika-chan! UK',
#    u'version': 5},
#   {u'changeset': 57534489,
#    u'id': 283885,
#    u'lat': 51.494974,
#    u'lon': 0.0155831,
#    u'tags': {u'leisure': u'park', u'name': u'Ecology Park'},
#    u'timestamp': u'2018-03-26T12:58:59Z',
#    u'type': u'node',
#    u'uid': 2076810,
#    u'user': u'MScanlon',
#    u'version': 5},
#   {u'changeset': 9789,
#    u'id': 284286,
#    u'lat': 51.6261803,
#    u'lon': -0.1772157,
#    u'tags': {u'created_by': u'YahooApplet 1.0'},
#    u'timestamp': u'2007-04-08T02:13:33Z',
#    u'type': u'node',
#    u'uid': 508,
#    u'user': u'Welshie',
#    u'version': 1},
#   {u'changeset': 11229929,
#    u'id': 285564,
#    u'lat': 51.615627,
#    u'lon': -0.2756168,
#    u'tags': {u'direction': u'clockwise', u'highway': u'mini_roundabout'},
#    u'timestamp': u'2012-04-08T20:28:39Z',
#    u'type': u'node',
#    u'uid': 243152,
#    u'user': u'ChinnorBoy',
#    u'version': 4},
#   {u'changeset': 21220093,
#    u'id': 287599,
#    u'lat': 51.4787409,
#    u'lon': -0.4077602,
#    u'tags': {u'crossing': u'traffic_signals', u'highway': u'crossing'},
#    u'timestamp': u'2014-03-21T00:37:26Z',
#    u'type': u'node',
#    u'uid': 1016290,
#    u'user': u'ika-chan! UK',
#    u'version': 5},
#   {u'changeset': 12049682,
#    u'id': 287822,
#    u'lat': 51.4795177,
#    u'lon': -0.4392111,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2012-06-28T20:43:21Z',
#    u'type': u'node',
#    u'uid': 607695,
#    u'user': u'cwood500',
#    u'version': 2},
#   {u'changeset': 24866422,
#    u'id': 287949,
#    u'lat': 51.4666584,
#    u'lon': -0.4224438,
#    u'tags': {u'crossing': u'traffic_signals',
#     u'crossing_ref': u'pelican',
#     u'highway': u'crossing'},
#    u'timestamp': u'2014-08-19T18:14:11Z',
#    u'type': u'node',
#    u'uid': 1016290,
#    u'user': u'ika-chan! UK',
#    u'version': 4},
#   {u'changeset': 34472812,
#    u'id': 292139,
#    u'lat': 51.4663028,
#    u'lon': -0.1504947,
#    u'tags': {u'crossing': u'traffic_signals', u'highway': u'traffic_signals'},
#    u'timestamp': u'2015-10-06T16:40:18Z',
#    u'type': u'node',
#    u'uid': 352985,
#    u'user': u'ecatmur',
#    u'version': 5},
#   {u'changeset': 33064958,
#    u'id': 292407,
#    u'lat': 51.4360907,
#    u'lon': -0.2559812,
#    u'tags': {u'bicycle': u'no',
#     u'crossing': u'traffic_signals',
#     u'crossing_ref': u'pegasus',
#     u'foot': u'no',
#     u'highway': u'crossing',
#     u'horse': u'yes',
#     u'source': u'Survey of 2015-08-01'},
#    u'timestamp': u'2015-08-03T09:51:09Z',
#    u'type': u'node',
#    u'uid': 1016290,
#    u'user': u'ika-chan! UK',
#    u'version': 7},
#   {u'changeset': 33064958,
#    u'id': 292409,
#    u'lat': 51.4359313,
#    u'lon': -0.2556575,
#    u'tags': {u'bicycle': u'yes',
#     u'crossing': u'traffic_signals',
#     u'highway': u'crossing',
#     u'horse': u'no',
#     u'source': u'Survey of 2015-08-01'},
#    u'timestamp': u'2015-08-03T09:51:09Z',
#    u'type': u'node',
#    u'uid': 1016290,
#    u'user': u'ika-chan! UK',
#    u'version': 11},
#   {u'changeset': 33064958,
#    u'id': 292413,
#    u'lat': 51.4356771,
#    u'lon': -0.2561612,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2015-08-03T09:51:10Z',
#    u'type': u'node',
#    u'uid': 1016290,
#    u'user': u'ika-chan! UK',
#    u'version': 6},
#   {u'changeset': 29296756,
#    u'id': 292444,
#    u'lat': 51.4467807,
#    u'lon': -0.2268358,
#    u'tags': {u'highway': u'motorway_junction', u'name': u"Tibbet's Corner"},
#    u'timestamp': u'2015-03-06T19:54:01Z',
#    u'type': u'node',
#    u'uid': 352985,
#    u'user': u'ecatmur',
#    u'version': 4},
#   {u'changeset': 25004181,
#    u'id': 292488,
#    u'lat': 51.4586039,
#    u'lon': -0.1950419,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2014-08-25T13:52:02Z',
#    u'type': u'node',
#    u'uid': 855535,
#    u'user': u"L'le Tom",
#    u'version': 4},
#   {u'changeset': 58866006,
#    u'id': 292497,
#    u'lat': 51.4593202,
#    u'lon': -0.190838,
#    u'tags': {u'bicycle': u'yes',
#     u'crossing': u'traffic_signals',
#     u'crossing_ref': u'toucan',
#     u'highway': u'crossing'},
#    u'timestamp': u'2018-05-11T03:04:46Z',
#    u'type': u'node',
#    u'uid': 322039,
#    u'user': u'MacLondon',
#    u'version': 9},
#   {u'changeset': 42668012,
#    u'id': 292559,
#    u'lat': 51.4719036,
#    u'lon': -0.1771589,
#    u'tags': {u'crossing': u'traffic_signals', u'highway': u'crossing'},
#    u'timestamp': u'2016-10-05T20:04:23Z',
#    u'type': u'node',
#    u'uid': 3716779,
#    u'user': u'Davidacious',
#    u'version': 5},
#   {u'changeset': 617063,
#    u'id': 292618,
#    u'lat': 51.4236029,
#    u'lon': -0.2755986,
#    u'tags': {u'highway': u'crossing'},
#    u'timestamp': u'2008-09-12T19:35:08Z',
#    u'type': u'node',
#    u'uid': 57618,
#    u'user': u'Ben_C',
#    u'version': 2},
#   {u'changeset': 617063,
#    u'id': 292621,
#    u'lat': 51.4217878,
#    u'lon': -0.2770337,
#    u'tags': {u'highway': u'crossing'},
#    u'timestamp': u'2008-09-12T19:35:08Z',
#    u'type': u'node',
#    u'uid': 57618,
#    u'user': u'Ben_C',
#    u'version': 3},
#   {u'changeset': 22137842,
#    u'id': 292680,
#    u'lat': 51.4171138,
#    u'lon': -0.3015255,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2014-05-05T00:40:44Z',
#    u'type': u'node',
#    u'uid': 2060582,
#    u'user': u'Tim Moss',
#    u'version': 17},
#   {u'changeset': 55341017,
#    u'id': 292702,
#    u'lat': 51.4108607,
#    u'lon': -0.2966647,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2018-01-11T03:52:07Z',
#    u'type': u'node',
#    u'uid': 322039,
#    u'user': u'MacLondon',
#    u'version': 8},
#   {u'changeset': 59781410,
#    u'id': 292707,
#    u'lat': 51.4104779,
#    u'lon': -0.3000829,
#    u'tags': {u'bus': u'yes',
#     u'local_ref': u'B',
#     u'name': u'Fairfield Bus Station',
#     u'public_transport': u'stop_position'},
#    u'timestamp': u'2018-06-12T14:57:06Z',
#    u'type': u'node',
#    u'uid': 2969887,
#    u'user': u'eastender',
#    u'version': 5},
#   {u'changeset': 6526081,
#    u'id': 292708,
#    u'lat': 51.4104845,
#    u'lon': -0.3005461,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2010-12-03T13:06:30Z',
#    u'type': u'node',
#    u'uid': 16703,
#    u'user': u'joelholdsworth',
#    u'version': 4},
#   {u'changeset': 7468917,
#    u'id': 292719,
#    u'lat': 51.4108451,
#    u'lon': -0.2920871,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2011-03-05T23:30:07Z',
#    u'type': u'node',
#    u'uid': 16703,
#    u'user': u'joelholdsworth',
#    u'version': 5},
#   {u'changeset': 16580685,
#    u'id': 292724,
#    u'lat': 51.4113696,
#    u'lon': -0.2909022,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2013-06-16T19:36:32Z',
#    u'type': u'node',
#    u'uid': 30525,
#    u'user': u'The Maarssen Mapper',
#    u'version': 12},
#   {u'changeset': 31983622,
#    u'id': 292729,
#    u'lat': 51.4081871,
#    u'lon': -0.3020021,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2015-06-15T13:09:55Z',
#    u'type': u'node',
#    u'uid': 16703,
#    u'user': u'joelholdsworth',
#    u'version': 11},
#   {u'changeset': 30937426,
#    u'id': 292732,
#    u'lat': 51.4077202,
#    u'lon': -0.3036966,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2015-05-09T13:56:10Z',
#    u'type': u'node',
#    u'uid': 16703,
#    u'user': u'joelholdsworth',
#    u'version': 9},
#   {u'changeset': 55864574,
#    u'id': 292739,
#    u'lat': 51.4054977,
#    u'lon': -0.3040104,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2018-01-29T16:16:14Z',
#    u'type': u'node',
#    u'uid': 322039,
#    u'user': u'MacLondon',
#    u'version': 7},
#   {u'changeset': 29090782,
#    u'id': 293525,
#    u'lat': 51.4726748,
#    u'lon': -0.2004943,
#    u'tags': {u'crossing': u'traffic_signals',
#     u'crossing_ref': u'pelican',
#     u'highway': u'traffic_signals'},
#    u'timestamp': u'2015-02-25T12:44:01Z',
#    u'type': u'node',
#    u'uid': 352985,
#    u'user': u'ecatmur',
#    u'version': 5},
#   {u'changeset': 32813962,
#    u'id': 293543,
#    u'lat': 51.4717278,
#    u'lon': -0.2050844,
#    u'tags': {u'highway': u'crossing'},
#    u'timestamp': u'2015-07-22T22:05:10Z',
#    u'type': u'node',
#    u'uid': 37137,
#    u'user': u'Derick Rethans',
#    u'version': 3},
#   {u'changeset': 36530721,
#    u'id': 293566,
#    u'lat': 51.4774509,
#    u'lon': -0.2018479,
#    u'tags': {u'crossing': u'traffic_signals', u'highway': u'crossing'},
#    u'timestamp': u'2016-01-12T15:00:09Z',
#    u'type': u'node',
#    u'uid': 352985,
#    u'user': u'ecatmur',
#    u'version': 4},
#   {u'changeset': 35802623,
#    u'id': 293568,
#    u'lat': 51.4786891,
#    u'lon': -0.2035183,
#    u'tags': {u'traffic_calming': u'bump'},
#    u'timestamp': u'2015-12-07T10:23:10Z',
#    u'type': u'node',
#    u'uid': 352985,
#    u'user': u'ecatmur',
#    u'version': 3},
#   {u'changeset': 33818969,
#    u'id': 293730,
#    u'lat': 51.4131461,
#    u'lon': -0.3683184,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2015-09-05T17:52:14Z',
#    u'type': u'node',
#    u'uid': 5541,
#    u'user': u'Ian Haylock',
#    u'version': 7},
#   {u'changeset': 18742067,
#    u'id': 294576,
#    u'lat': 51.4755562,
#    u'lon': -0.3911748,
#    u'tags': {u'bicycle': u'yes',
#     u'crossing': u'traffic_signals',
#     u'crossing_ref': u'toucan',
#     u'foot': u'yes',
#     u'highway': u'crossing'},
#    u'timestamp': u'2013-11-06T06:44:05Z',
#    u'type': u'node',
#    u'uid': 1016290,
#    u'user': u'ika-chan! UK',
#    u'version': 8},
#   {u'changeset': 16585933,
#    u'id': 294673,
#    u'lat': 51.4817648,
#    u'lon': -0.3469177,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2013-06-17T08:44:25Z',
#    u'type': u'node',
#    u'uid': 1016290,
#    u'user': u'ika-chan! UK',
#    u'version': 5},
#   {u'changeset': 25115590,
#    u'id': 294791,
#    u'lat': 51.4636131,
#    u'lon': -0.1329738,
#    u'tags': {u'crossing': u'traffic_signals',
#     u'crossing_ref': u'pelican',
#     u'highway': u'crossing'},
#    u'timestamp': u'2014-08-30T11:14:21Z',
#    u'type': u'node',
#    u'uid': 1295,
#    u'user': u'robert',
#    u'version': 8},
#   {u'changeset': 20380563,
#    u'id': 294839,
#    u'lat': 51.4612125,
#    u'lon': -0.1433913,
#    u'tags': {u'crossing': u'traffic_signals', u'highway': u'traffic_signals'},
#    u'timestamp': u'2014-02-04T20:42:54Z',
#    u'type': u'node',
#    u'uid': 855535,
#    u'user': u"L'le Tom",
#    u'version': 7},
#   {u'changeset': 21233569,
#    u'id': 294901,
#    u'lat': 51.4888536,
#    u'lon': -0.3120232,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2014-03-21T20:22:01Z',
#    u'type': u'node',
#    u'uid': 1016290,
#    u'user': u'ika-chan! UK',
#    u'version': 3},
#   {u'changeset': 21315168,
#    u'id': 294909,
#    u'lat': 51.490936,
#    u'lon': -0.3063484,
#    u'tags': {u'bicycle': u'yes',
#     u'crossing': u'traffic_signals',
#     u'crossing_ref': u'toucan',
#     u'foot': u'yes',
#     u'highway': u'crossing'},
#    u'timestamp': u'2014-03-25T22:49:18Z',
#    u'type': u'node',
#    u'uid': 1016290,
#    u'user': u'ika-chan! UK',
#    u'version': 4},
#   {u'changeset': 24764323,
#    u'id': 294944,
#    u'lat': 51.4914916,
#    u'lon': -0.2926519,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2014-08-15T10:48:18Z',
#    u'type': u'node',
#    u'uid': 1016290,
#    u'user': u'ika-chan! UK',
#    u'version': 11},
#   {u'changeset': 58936004,
#    u'id': 295241,
#    u'lat': 51.4918915,
#    u'lon': -0.2819435,
#    u'tags': {u'bicycle': u'yes',
#     u'crossing': u'traffic_signals',
#     u'crossing_ref': u'toucan',
#     u'highway': u'crossing'},
#    u'timestamp': u'2018-05-13T23:09:59Z',
#    u'type': u'node',
#    u'uid': 322039,
#    u'user': u'MacLondon',
#    u'version': 9},
#   {u'changeset': 53510257,
#    u'id': 295274,
#    u'lat': 51.4893105,
#    u'lon': -0.2771888,
#    u'tags': {u'exit_to': u'A406 North Circular;A205 South Circular;A315 Chiswick',
#     u'highway': u'motorway_junction',
#     u'layer': u'3',
#     u'name': u'Chiswick Roundabout',
#     u'ref': u'1'},
#    u'timestamp': u'2017-11-04T17:38:23Z',
#    u'type': u'node',
#    u'uid': 322039,
#    u'user': u'MacLondon',
#    u'version': 16},
#   {u'changeset': 16384724,
#    u'id': 295649,
#    u'lat': 51.457253,
#    u'lon': -0.3221071,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2013-06-01T23:24:05Z',
#    u'type': u'node',
#    u'uid': 1174735,
#    u'user': u'markptompsett',
#    u'version': 6},
#   {u'changeset': 16384724,
#    u'id': 295651,
#    u'lat': 51.4571457,
#    u'lon': -0.3223679,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2013-06-01T23:24:05Z',
#    u'type': u'node',
#    u'uid': 1174735,
#    u'user': u'markptompsett',
#    u'version': 6},
#   {u'changeset': 16384724,
#    u'id': 295653,
#    u'lat': 51.457506,
#    u'lon': -0.3223937,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2013-06-01T23:24:05Z',
#    u'type': u'node',
#    u'uid': 1174735,
#    u'user': u'markptompsett',
#    u'version': 6},
#   {u'changeset': 11073047,
#    u'id': 295715,
#    u'lat': 51.6359119,
#    u'lon': -0.1664499,
#    u'tags': {u'highway': u'mini_roundabout'},
#    u'timestamp': u'2012-03-23T12:57:33Z',
#    u'type': u'node',
#    u'uid': 403871,
#    u'user': u'busdoc',
#    u'version': 2},
#   {u'changeset': 17168130,
#    u'id': 295836,
#    u'lat': 51.4351354,
#    u'lon': -0.3851054,
#    u'tags': {u'highway': u'motorway_junction', u'name': u'Apex Corner'},
#    u'timestamp': u'2013-07-31T16:03:29Z',
#    u'type': u'node',
#    u'uid': 508,
#    u'user': u'Welshie',
#    u'version': 3},
#   {u'changeset': 343865,
#    u'id': 296152,
#    u'lat': 51.4928531,
#    u'lon': -0.251416,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2008-08-20T02:08:31Z',
#    u'type': u'node',
#    u'uid': 28705,
#    u'user': u'marnen',
#    u'version': 9},
#   {u'changeset': 55167644,
#    u'id': 296250,
#    u'lat': 51.4118713,
#    u'lon': -0.3061163,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2018-01-04T19:24:50Z',
#    u'type': u'node',
#    u'uid': 322039,
#    u'user': u'MacLondon',
#    u'version': 8},
#   {u'changeset': 49076434,
#    u'id': 296257,
#    u'lat': 51.4127788,
#    u'lon': -0.3050129,
#    u'tags': {u'bicycle': u'yes',
#     u'crossing': u'traffic_signals',
#     u'crossing_ref': u'toucan',
#     u'highway': u'crossing'},
#    u'timestamp': u'2017-05-29T15:45:23Z',
#    u'type': u'node',
#    u'uid': 322039,
#    u'user': u'MacLondon',
#    u'version': 6},
#   {u'changeset': 55167644,
#    u'id': 296258,
#    u'lat': 51.4126108,
#    u'lon': -0.3050781,
#    u'tags': {u'bicycle': u'yes',
#     u'crossing': u'traffic_signals',
#     u'crossing_ref': u'toucan',
#     u'highway': u'crossing'},
#    u'timestamp': u'2018-01-04T19:24:51Z',
#    u'type': u'node',
#    u'uid': 322039,
#    u'user': u'MacLondon',
#    u'version': 4},
#   {u'changeset': 55167644,
#    u'id': 296259,
#    u'lat': 51.4128064,
#    u'lon': -0.3051521,
#    u'tags': {u'highway': u'traffic_signals'},
#    u'timestamp': u'2018-01-04T19:24:51Z',
#    u'type': u'node',
#    u'uid': 322039,
#    u'user': u'MacLondon',
#    u'version': 8},
#   ...],
#  u'generator': u'Overpass API 0.7.55.4 3079d8ea',
#  u'osm3s': {u'copyright': u'The data included in this document is from www.openstreetmap.org. The data is made available under ODbL.',
#   u'timestamp_areas_base': u'2018-09-12T21:51:02Z',
#   u'timestamp_osm_base': u'2018-09-12T22:44:04Z'},
#  u'version': 0.6}

# %%
list(tags)
# Out:
# [[[...], [...], [...], [...], [...]],
#  [[...], [...], [...], [...], [...]],
#  [[...], [...], [...], [...], [...]],
#  [[...], [...], [...], [...], [...]],
#  [[...], [...], [...], [...], [...]]]

# %%
tag=[]

for anode in data['elements']:
    atag=anode['tags'].keys()
    tag.append(atag)

tag
# Out:
# [[u'traffic_signals:direction', u'highway'],
#  [u'barrier'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'crossing', u'highway', u'crossing:island'],
#  [u'highway'],
#  [u'highway'],
#  [u'crossing', u'highway', u'crossing:island'],
#  [u'highway'],
#  [u'highway'],
#  [u'crossing', u'highway'],
#  [u'crossing', u'crossing_ref', u'bicycle', u'segregated', u'highway'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'highway'],
#  [u'traffic_signals', u'highway'],
#  [u'created_by'],
#  [u'crossing_ref', u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'crossing', u'crossing_ref', u'bicycle', u'highway', u'barrier'],
#  [u'highway'],
#  [u'source', u'direction', u'highway'],
#  [u'direction', u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'crossing', u'highway'],
#  [u'crossing', u'highway'],
#  [u'highway'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'button_operated',
#   u'crossing',
#   u'crossing_ref',
#   u'traffic_signals:sound',
#   u'highway'],
#  [u'crossing', u'highway'],
#  [u'crossing', u'crossing_ref', u'bicycle', u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'crossing', u'traffic_calming', u'wheelchair'],
#  [u'created_by'],
#  [u'direction', u'highway'],
#  [u'created_by'],
#  [u'direction', u'highway'],
#  [u'direction', u'highway'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'highway'],
#  [u'created_by'],
#  [u'direction', u'highway'],
#  [u'crossing', u'source', u'crossing_ref', u'highway'],
#  [u'crossing', u'crossing_ref', u'bicycle', u'segregated', u'highway'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'created_by'],
#  [u'highway'],
#  [u'waterway'],
#  [u'highway'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'highway'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'crossing', u'crossing_ref', u'name', u'highway'],
#  [u'direction', u'highway'],
#  [u'foot', u'barrier'],
#  [u'direction', u'highway'],
#  [u'highway'],
#  [u'traffic_calming'],
#  [u'traffic_calming'],
#  [u'direction', u'highway'],
#  [u'direction', u'highway'],
#  [u'cycleway'],
#  [u'highway'],
#  [u'created_by'],
#  [u'randomjunk_bot'],
#  [u'traffic_calming'],
#  [u'crossing', u'crossing_ref', u'junction', u'name', u'highway'],
#  [u'highway'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'maxspeed', u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'crossing', u'crossing_ref', u'highway', u'crossing:island'],
#  [u'randomjunk_bot'],
#  [u'highway'],
#  [u'highway'],
#  [u'traffic_calming'],
#  [u'randomjunk_bot'],
#  [u'highway', u'randomjunk_bot'],
#  [u'highway'],
#  [u'highway'],
#  [u'created_by'],
#  [u'randomjunk_bot'],
#  [u'created_by', u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'highway'],
#  [u'crossing', u'bicycle', u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'bus', u'local_ref', u'name', u'public_transport'],
#  [u'crossing', u'highway'],
#  [u'crossing', u'sloped_curb', u'crossing_ref', u'kerb', u'highway'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'highway'],
#  [u'crossing', u'highway'],
#  [u'crossing', u'highway'],
#  [u'highway'],
#  [u'crossing', u'highway'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'highway'],
#  [u'crossing', u'foot', u'crossing_ref', u'segregated', u'highway'],
#  [u'crossing', u'foot', u'crossing_ref', u'highway'],
#  [u'name:cy',
#   u'name:ko',
#   u'name:cv',
#   u'name:cu',
#   u'name:cs',
#   u'name:tt',
#   u'name:co',
#   u'name:kv',
#   u'name:ku',
#   u'name:tl',
#   u'name:ta',
#   u'name:tg',
#   u'name:ca',
#   u'is_in',
#   u'name:bat-smg',
#   u'name:ka',
#   u'name:frp',
#   u'ele',
#   u'name:tr',
#   u'name:tet',
#   u'name:kn',
#   u'name:lv',
#   u'name:lt',
#   u'name:el',
#   u'name:kk',
#   u'name:ur',
#   u'name:la',
#   u'name:uk',
#   u'name:li',
#   u'name:ln',
#   u'name:lo',
#   u'wikimedia_commons',
#   u'name:kw',
#   u'name:eo',
#   u'name:en',
#   u'name',
#   u'name:th',
#   u'name:lij',
#   u'is_in:continent',
#   u'name:eu',
#   u'name:ilo',
#   u'name:es',
#   u'name:rm',
#   u'name:lez',
#   u'is_capital',
#   u'name:yue',
#   u'name:gan',
#   u'name:nah',
#   u'name:ar',
#   u'name:eml',
#   u'name:is',
#   u'name:ckb',
#   u'name:am',
#   u'name:it',
#   u'name:an',
#   u'name:ru',
#   u'name:ast',
#   u'name:af',
#   u'name:zu',
#   u'name:lbe',
#   u'name:scn',
#   u'name:no',
#   u'wikipedia',
#   u'name:pms',
#   u'name:nrm',
#   u'name:ky',
#   u'capital',
#   u'name:te',
#   u'name:zh',
#   u'name:sk',
#   u'name:ja',
#   u'name:si',
#   u'name:zh-traditional',
#   u'name:sc',
#   u'name:br',
#   u'name:arc',
#   u'name:bn',
#   u'name:bo',
#   u'name:sa',
#   u'name:arz',
#   u'name:be',
#   u'name:bg',
#   u'name:krc',
#   u'name:sq',
#   u'name:mrj',
#   u'name:jbo',
#   u'name:bcl',
#   u'name:xmf',
#   u'place',
#   u'name:sah',
#   u'name:mzn',
#   u'name:udm',
#   u'name:pt',
#   u'name:ps',
#   u'name:tpi',
#   u'name:oc',
#   u'name:ro',
#   u'name:diq',
#   u'name:sv',
#   u'name:os',
#   u'name:or',
#   u'name:pl',
#   u'name:de',
#   u'name:ba',
#   u'name:cdo',
#   u'name:mhr',
#   u'name:rue',
#   u'website',
#   u'admin_level',
#   u'name:sco',
#   u'name:hi',
#   u'name:my',
#   u'name:he',
#   u'name:roa-rup',
#   u'name:zh-classical',
#   u'name:hy',
#   u'name:ht',
#   u'name:hu',
#   u'name:vec',
#   u'population',
#   u'name:pnt',
#   u'name:szl',
#   u'name:nap',
#   u'name:lmo',
#   u'name:zh_pinyin',
#   u'name:pnb',
#   u'name:yi',
#   u'name:be-tarask',
#   u'name:yo',
#   u'name:mt',
#   u'name:mr',
#   u'name:koi',
#   u'name:lad',
#   u'wikidata',
#   u'name:vi',
#   u'name:ml',
#   u'name:nds-nl',
#   u'name:mn',
#   u'name:mi',
#   u'name:mk',
#   u'name:zh-simplified',
#   u'name:fa',
#   u'name:ab',
#   u'is_in:country',
#   u'name:fi',
#   u'name:ext',
#   u'name:mwl',
#   u'note',
#   u'name:tzl',
#   u'name:fr',
#   u'name:fy',
#   u'name:roa-tara',
#   u'name:sr',
#   u'name:nl',
#   u'name:new',
#   u'name:zea',
#   u'is_in:country_code',
#   u'name:ne',
#   u'name:pcd',
#   u'name:wo',
#   u'name:ang',
#   u'name:ga',
#   u'name:gd',
#   u'name:vls',
#   u'name:haw',
#   u'name:gn',
#   u'name:gl',
#   u'name:gv',
#   u'name:gu',
#   u'is_in:iso_3166_2',
#   u'name:wuu'],
#  [u'highway', u'randomjunk_bot'],
#  [u'crossing_ref',
#   u'junction',
#   u'name',
#   u'wikipedia',
#   u'wikidata',
#   u'crossing',
#   u'highway'],
#  [u'note'],
#  [u'highway'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'traffic_calming', u'surface'],
#  [u'junction', u'name', u'junction_ref'],
#  [u'highway'],
#  [u'source'],
#  [u'enforcement', u'highway'],
#  [u'highway', u'randomjunk_bot'],
#  [u'source', u'highway'],
#  [u'highway', u'randomjunk_bot'],
#  [u'junction', u'name'],
#  [u'curve_geometry'],
#  [u'curve_geometry'],
#  [u'curve_geometry'],
#  [u'created_by'],
#  [u'traffic_calming'],
#  [u'barrier'],
#  [u'highway'],
#  [u'kerb'],
#  [u'highway'],
#  [u'addr:housenumber',
#   u'toilets',
#   u'amenity',
#   u'name',
#   u'addr:postcode',
#   u'contact:website',
#   u'contact:phone',
#   u'opening_hours',
#   u'toilets:access',
#   u'old_name',
#   u'toilets:wheelchair',
#   u'wheelchair',
#   u'addr:street'],
#  [u'created_by'],
#  [u'crossing', u'highway'],
#  [u'highway'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'highway'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'crossing', u'highway'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'highway'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot_1', u'randomjunk_bot'],
#  [u'randomjunk_bot_1', u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'highway'],
#  [u'highway'],
#  [u'randomjunk_bot'],
#  [u'highway'],
#  [u'crossing', u'bicycle', u'highway'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'crossing', u'source', u'crossing_ref', u'highway'],
#  [u'highway'],
#  [u'created_by'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'button_operated', u'crossing', u'crossing_ref', u'highway'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'randomjunk_bot'],
#  [u'created_by'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'highway'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'highway'],
#  [u'randomjunk_bot'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'randomjunk_bot'],
#  [u'traffic_signals', u'highway'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'highway'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'randomjunk_bot'],
#  [u'highway'],
#  [u'crossing', u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'direction', u'highway'],
#  [u'maxspeed', u'highway'],
#  [u'highway'],
#  [u'created_by'],
#  [u'highway'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'highway'],
#  [u'amenity', u'capacity', u'name', u'network'],
#  [u'randomjunk_bot'],
#  [u'highway'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'direction', u'highway'],
#  [u'highway'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot_1', u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'randomjunk_bot'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'crossing', u'bicycle', u'highway'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'horse', u'bicycle', u'barrier', u'access', u'motor_vehicle', u'foot'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'created_by'],
#  [u'highway'],
#  [u'randomjunk_bot'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'direction', u'highway'],
#  [u'direction', u'highway'],
#  [u'randomjunk_bot'],
#  [u'waterway'],
#  [u'opening_hours', u'barrier'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'randomjunk_bot'],
#  [u'bus', u'local_ref', u'name', u'public_transport'],
#  [u'cycleway'],
#  [u'crossing', u'highway'],
#  [u'highway', u'randomjunk_bot'],
#  [u'highway'],
#  [u'highway'],
#  [u'crossing', u'highway'],
#  [u'bus', u'local_ref', u'name', u'public_transport'],
#  [u'highway'],
#  [u'highway'],
#  [u'randomjunk_bot'],
#  [u'created_by'],
#  [u'highway'],
#  [u'highway'],
#  [u'traffic_calming'],
#  [u'highway'],
#  [u'highway'],
#  [u'crossing_ref', u'highway'],
#  [u'crossing_ref',
#   u'source',
#   u'fixme',
#   u'sloped_curb',
#   u'crossing',
#   u'kerb',
#   u'highway'],
#  [u'source', u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'traffic_calming'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'created_by', u'randomjunk_bot'],
#  [u'created_by', u'randomjunk_bot'],
#  [u'created_by', u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'bus', u'local_ref', u'name', u'public_transport'],
#  [u'amenity', u'name'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'crossing_ref', u'bicycle', u'horse', u'foot', u'crossing', u'highway'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'traffic_signals:direction', u'highway'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'randomjunk_bot'],
#  [u'highway', u'randomjunk_bot'],
#  [u'highway'],
#  [u'highway'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'highway'],
#  [u'randomjunk_bot'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'randomjunk_bot'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'highway'],
#  [u'layer'],
#  [u'randomjunk_bot'],
#  [u'traffic_calming'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'traffic_signals:direction', u'highway'],
#  [u'highway', u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'highway'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'bus', u'local_ref', u'name', u'public_transport'],
#  [u'created_by'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'highway'],
#  [u'randomjunk_bot'],
#  [u'crossing', u'foot', u'crossing_ref', u'bicycle', u'highway'],
#  [u'randomjunk_bot'],
#  [u'crossing', u'highway'],
#  [u'traffic_calming'],
#  [u'highway', u'crossing:island'],
#  [u'amenity', u'capacity'],
#  [u'randomjunk_bot'],
#  [u'traffic_signals', u'highway'],
#  [u'maxspeed', u'highway'],
#  [u'randomjunk_bot'],
#  [u'crossing', u'crossing_ref', u'highway', u'crossing:island'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'highway'],
#  [u'highway'],
#  [u'bus', u'local_ref', u'name', u'public_transport'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'waterway'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'crossing_ref',
#   u'bicycle',
#   u'segregated',
#   u'randomjunk_bot',
#   u'crossing',
#   u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'created_by', u'randomjunk_bot'],
#  [u'created_by', u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'randomjunk_bot'],
#  [u'created_by', u'randomjunk_bot'],
#  [u'created_by', u'randomjunk_bot'],
#  [u'highway'],
#  [u'created_by', u'randomjunk_bot'],
#  [u'created_by'],
#  [u'randomjunk_bot'],
#  [u'highway'],
#  [u'highway'],
#  [u'created_by'],
#  [u'source', u'highway'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'source', u'highway'],
#  [u'name', u'highway'],
#  [u'name', u'highway'],
#  [u'highway'],
#  [u'direction', u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'crossing', u'crossing_ref', u'bicycle', u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'name', u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'traffic_calming'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'junction', u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'highway'],
#  [u'crossing', u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'traffic_calming'],
#  [u'highway'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'bus', u'local_ref', u'name', u'public_transport'],
#  [u'highway'],
#  [u'highway'],
#  [u'direction', u'highway'],
#  [u'direction', u'highway'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'highway'],
#  [u'created_by'],
#  [u'highway'],
#  [u'barrier'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'ref', u'not:name', u'name', u'highway'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'highway'],
#  [u'created_by'],
#  [u'highway'],
#  [u'highway'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'name', u'wikipedia', u'wikidata', u'place', u'highway', u'is_in'],
#  [u'highway'],
#  [u'name'],
#  [u'highway'],
#  [u'highway'],
#  [u'is_in'],
#  [u'highway'],
#  [u'name', u'highway'],
#  [u'direction', u'highway'],
#  [u'created_by'],
#  [u'fixme'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'fixme'],
#  [u'created_by'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'source', u'bus', u'local_ref', u'name', u'public_transport'],
#  [u'source', u'bus', u'local_ref', u'name', u'public_transport'],
#  [u'direction', u'highway'],
#  [u'direction', u'highway'],
#  [u'name', u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'name', u'highway'],
#  [u'highway'],
#  [u'bus', u'local_ref', u'name', u'public_transport'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'direction', u'highway'],
#  [u'highway'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'created_by'],
#  [u'name', u'highway'],
#  [u'name', u'highway'],
#  [u'highway'],
#  [u'direction', u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'name', u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'cycleway'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'highway'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'highway'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'crossing', u'foot', u'crossing_ref', u'bicycle', u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'source', u'bridge:support'],
#  [u'highway'],
#  [u'highway'],
#  [u'direction', u'highway'],
#  [u'highway'],
#  [u'curve_geometry'],
#  [u'highway'],
#  [u'direction', u'highway'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'traffic_calming'],
#  [u'highway'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'highway'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'created_by'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'bus', u'local_ref', u'name', u'public_transport'],
#  [u'bus', u'local_ref', u'name', u'public_transport'],
#  [u'traffic_calming'],
#  [u'crossing', u'traffic_calming', u'highway'],
#  [u'direction', u'highway'],
#  [u'traffic_calming'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'highway'],
#  [u'traffic_calming'],
#  [u'bus', u'local_ref', u'public_transport'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'crossing', u'crossing_ref', u'traffic_calming', u'highway'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'crossing', u'crossing_ref', u'highway', u'crossing:island'],
#  [u'crossing', u'crossing_ref', u'kerb', u'highway'],
#  [u'highway'],
#  [u'crossing', u'crossing_ref', u'highway', u'crossing:island'],
#  [u'crossing', u'crossing_ref', u'highway', u'crossing:island'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'barrier'],
#  [u'direction', u'highway'],
#  [u'bus', u'local_ref', u'name', u'public_transport'],
#  [u'highway'],
#  [u'highway'],
#  [u'place', u'name', u'is_in'],
#  [u'bus', u'name', u'public_transport'],
#  [u'direction', u'highway'],
#  [u'highway'],
#  [u'direction', u'highway'],
#  [u'highway'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'traffic_calming'],
#  [u'direction', u'highway'],
#  [u'bus', u'local_ref', u'name', u'public_transport'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'bus', u'local_ref', u'name', u'public_transport'],
#  [u'traffic_calming'],
#  [u'direction', u'highway'],
#  [u'source'],
#  [u'created_by'],
#  [u'highway'],
#  [u'wikidata', u'wikipedia', u'place', u'name', u'is_in'],
#  [u'direction', u'highway'],
#  [u'direction', u'highway'],
#  [u'direction', u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'exit_to', u'ref', u'name', u'highway'],
#  [u'direction', u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'wikidata', u'wikipedia', u'place', u'name', u'is_in'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'exit_to', u'ref', u'name', u'highway'],
#  [u'highway'],
#  [u'exit_to', u'name', u'highway', u'source:exit_to'],
#  [u'highway'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'crossing', u'crossing_ref', u'bicycle', u'highway'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'crossing', u'crossing_ref', u'bicycle', u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'ref', u'alt_name', u'highway', u'name'],
#  [u'ref', u'name', u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'layer', u'exit_to', u'name', u'alt_name', u'ref', u'highway'],
#  [u'ref', u'alt_name', u'highway', u'name'],
#  [u'layer', u'exit_to', u'name', u'destination', u'ref', u'highway'],
#  [u'layer', u'exit_to', u'name', u'destination', u'ref', u'highway'],
#  [u'highway'],
#  [u'destination:ref', u'ref', u'layer', u'highway', u'name'],
#  [u'highway'],
#  [u'highway'],
#  [u'created_by'],
#  [u'direction', u'highway'],
#  [u'highway'],
#  [u'direction', u'highway'],
#  [u'highway'],
#  [u'name', u'highway'],
#  [u'name', u'highway'],
#  [u'highway'],
#  [u'name', u'highway'],
#  [u'name', u'highway'],
#  [u'name', u'highway'],
#  [u'name', u'highway'],
#  [u'name', u'highway', u'old_name'],
#  [u'highway'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'name', u'highway'],
#  [u'created_by'],
#  [u'direction', u'highway'],
#  [u'direction', u'highway'],
#  [u'direction', u'highway'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'created_by'],
#  [u'direction', u'highway'],
#  [u'highway'],
#  [u'crossing', u'highway'],
#  [u'maxspeed', u'highway'],
#  [u'crossing', u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'crossing', u'highway'],
#  [u'barrier'],
#  [u'highway'],
#  [u'crossing_ref',
#   u'bicycle',
#   u'button_operated',
#   u'supervised',
#   u'crossing',
#   u'traffic_signals:sound',
#   u'highway'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'name'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'direction', u'highway'],
#  [u'fixme', u'not:fixme'],
#  [u'highway'],
#  [u'traffic_calming'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'traffic_calming'],
#  [u'traffic_calming'],
#  [u'direction', u'highway'],
#  [u'highway', u'abutters'],
#  [u'bus', u'local_ref', u'name', u'public_transport'],
#  [u'highway'],
#  [u'direction', u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'name', u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'crossing', u'highway', u'crossing:island'],
#  [u'wikidata', u'wikipedia', u'place', u'name', u'is_in'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'traffic_calming'],
#  [u'direction', u'highway'],
#  [u'note', u'direction', u'highway'],
#  [u'source', u'traffic_calming'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'barrier'],
#  [u'crossing', u'highway'],
#  [u'highway'],
#  [u'created_by'],
#  [u'highway'],
#  [u'highway'],
#  [u'direction', u'highway'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'highway'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'layer', u'name', u'destination', u'destination:ref', u'ref', u'highway'],
#  [u'curve_geometry'],
#  [u'barrier'],
#  [u'highway'],
#  [u'highway'],
#  [u'maxspeed', u'name', u'highway'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'crossing', u'highway'],
#  [u'highway'],
#  [u'maxspeed', u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'crossing_ref', u'highway'],
#  [u'crossing', u'highway'],
#  [u'highway'],
#  [u'traffic_signals', u'highway'],
#  [u'maxspeed', u'highway'],
#  [u'crossing', u'highway'],
#  [u'highway'],
#  [u'created_by'],
#  [u'highway'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'highway'],
#  [u'created_by'],
#  [u'highway'],
#  [u'highway'],
#  [u'direction', u'highway'],
#  [u'direction', u'highway'],
#  [u'created_by'],
#  [u'direction', u'highway'],
#  [u'highway', u'crossing:island'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'created_by'],
#  [u'created_by'],
#  [u'crossing', u'wheelchair', u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'postal_code', u'wikidata', u'junction', u'name'],
#  [u'crossing', u'source', u'highway'],
#  [u'highway'],
#  [u'source', u'barrier'],
#  [u'highway'],
#  [u'direction', u'highway'],
#  [u'highway'],
#  [u'name', u'highway'],
#  [u'crossing', u'junction', u'name', u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'source', u'highway'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'crossing_ref', u'highway'],
#  [u'created_by'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'name', u'highway'],
#  [u'highway'],
#  [u'name', u'highway'],
#  [u'highway'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'crossing', u'crossing_ref', u'bicycle', u'segregated', u'highway'],
#  [u'highway'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'crossing', u'highway'],
#  [u'direction', u'highway'],
#  [u'direction', u'highway'],
#  [u'abutters'],
#  [u'abutters'],
#  [u'direction', u'highway'],
#  [u'direction', u'highway'],
#  [u'highway'],
#  [u'traffic_calming'],
#  [u'created_by'],
#  [u'crossing', u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'crossing_ref',
#   u'bicycle',
#   u'horse',
#   u'supervised',
#   u'crossing',
#   u'highway'],
#  [u'direction', u'highway'],
#  [u'direction', u'highway'],
#  [u'direction', u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'traffic_calming'],
#  [u'traffic_calming'],
#  [u'traffic_calming'],
#  [u'highway'],
#  [u'crossing', u'bicycle', u'highway'],
#  [u'highway'],
#  [u'crossing', u'highway'],
#  [u'highway'],
#  [u'traffic_calming'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'highway'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'crossing', u'crossing_ref', u'traffic_calming', u'surface', u'highway'],
#  [u'crossing', u'highway'],
#  [u'highway'],
#  [u'created_by'],
#  [u'direction', u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'created_by'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'bus', u'local_ref', u'name', u'public_transport'],
#  [u'highway'],
#  [u'wikidata', u'wikipedia', u'place', u'name', u'is_in'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'created_by'],
#  [u'traffic_signals', u'highway'],
#  [u'highway', u'created_by'],
#  [u'highway'],
#  [u'highway'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'name', u'leisure'],
#  [u'created_by'],
#  [u'direction', u'highway'],
#  [u'crossing', u'highway'],
#  [u'highway'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'crossing', u'highway'],
#  [u'crossing_ref',
#   u'bicycle',
#   u'source',
#   u'horse',
#   u'foot',
#   u'crossing',
#   u'highway'],
#  [u'crossing', u'source', u'horse', u'bicycle', u'highway'],
#  [u'highway'],
#  [u'name', u'highway'],
#  [u'highway'],
#  [u'crossing', u'crossing_ref', u'bicycle', u'highway'],
#  [u'crossing', u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'bus', u'local_ref', u'name', u'public_transport'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'highway'],
#  [u'crossing', u'highway'],
#  [u'traffic_calming'],
#  [u'highway'],
#  [u'crossing', u'foot', u'crossing_ref', u'bicycle', u'highway'],
#  [u'highway'],
#  [u'crossing', u'crossing_ref', u'highway'],
#  [u'crossing', u'highway'],
#  [u'highway'],
#  [u'crossing', u'foot', u'crossing_ref', u'bicycle', u'highway'],
#  [u'highway'],
#  [u'crossing', u'crossing_ref', u'bicycle', u'highway'],
#  [u'layer', u'exit_to', u'ref', u'name', u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'name', u'highway'],
#  [u'highway'],
#  [u'highway'],
#  [u'crossing', u'crossing_ref', u'bicycle', u'highway'],
#  [u'crossing', u'crossing_ref', u'bicycle', u'highway'],
#  [u'highway'],
#  ...]

# %%
taglist=[]

for atag in tag:
    tagl=list(atag)
    taglist.append(tagl)


list(set(taglist))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-18f0cc3b0646> in <module>()
#       8
#       9
# ---> 10 list(set(taglist))
#
# TypeError: unhashable type: 'list'

# %%
import numpy as np
import matplotlib.pyplot as plt

# Collect coords into list
coords = []
for element in data['elements']:
  if element['type'] == 'node':
    lon = element['lon']
    lat = element['lat']
    coords.append((lon, lat))
  elif 'center' in element:
    lon = element['center']['lon']
    lat = element['center']['lat']
    coords.append((lon, lat))

# Convert coordinates into numpy array
X = np.array(coords)

plt.plot(X[:, 0], X[:, 1], 'o')
plt.title('Bars in Great Britain ')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.axis('equal')
plt.show()
